# %%
from pyautogui import *
import pyautogui
import time
import keyboard
import numpy as np
import random
#import wxwidgets

# %%
# GLOBALS
training_menu = (130, 636)
indy_training_area = (1271, 162)
first_player_area = (1267, 405)
#top_right_praise_button = (3488, 261)
top_right_praise_button = (3505,255)
#praise_button = (1809, 1102)
praise_button = (1862, 1102)
#end_qc_top_right = (2690, 382)
end_qc_top_right = (2681, 388)
hover_duration = 0.1
players_to_praise = 25
y_iter = 89

# %%
# Define separate move and click functions
def my_move(coord_tuple):
    x, y = coord_tuple
    pyautogui.moveTo(x, y, duration=hover_duration)


def my_click():
    pyautogui.mouseDown()
    #time.sleep(0.1)
    pyautogui.mouseUp()

# %%
# To display mouse position
pyautogui.displayMousePosition()

# %%
# Training area setup
time.sleep(5)

# Navigate to Training Menu
my_move(training_menu)
my_click()

# Click on Individual Training
time.sleep(2)
my_move(indy_training_area)
my_click()

# %%
time.sleep(5)
indy_training_area = (1149, 151)
first_player_area = (828, 419)

# Click on Individual Training
time.sleep(2)
my_move(indy_training_area)
my_click()

# Move to first player
my_move(first_player_area)
my_click()

#pyautogui.moveTo(828, 419, duration=hover_duration)
#pyautogui.mouseDown()
#time.sleep(0.2)
#pyautogui.mouseUp()

# %%
test_x, test_y = top_right_praise_button
print(pyautogui.pixel(test_x, test_y))
(255, 255,255) == pyautogui.pixel(test_x, test_y)

# %%
# Nave method

time.sleep(5)
for i in range(players_to_praise):
    # Praise top right
    #my_move(top_right_praise_button)
    test_x, test_y = top_right_praise_button
    #print(pyautogui.pixel(test_x, test_y))
    if pyautogui.pixel(test_x, test_y) == (255,255,255):
        my_move(top_right_praise_button)
        my_click()
        # Click 1st praise choice
        my_move(praise_button)
        my_click()
        # End chat 
        my_move(end_qc_top_right)
        my_click()
        print("Pressing down arrow after clicking praise")
        pyautogui.press('down')
    else:
        print("Pressing down after failing white pixel test")
        pyautogui.press('down')
        continue
    printprint("Pressing down default")
    pyautogui.press('down')
    print(f"Iteration is {i}")

    # Push down arrow
    #pyautogui.press('down')

# %%
# Positional method

time.sleep(10)

def my_praise_click():
    my_move(top_right_praise_button)
    my_click()
    # Click 1st praise choice
    my_move(praise_button)
    my_click()
    # End chat 
    my_move(end_qc_top_right)
    my_click()

# move to starting position

#my_move(first_player_area)
my_click()

#player_x, player_y = first_player_area
#player_x, player_y = (1312, 422)
player_x, player_y = (1310, 419)


player_pos = (player_x, player_y)
my_move(player_pos)

test_x, test_y = top_right_praise_button
# iterate over number of players by moving down a specific Y pixel amount
for i in range(players_to_praise):
    # iterate across x values
    green_x, green_y = 1280, player_y
    green_counter = 0
    for j in range(50):
        red = pyautogui.pixel(green_x, green_y)[0]
        green =  pyautogui.pixel(green_x, green_y)[1]
        blue =  pyautogui.pixel(green_x, green_y)[2]
        if green > 170 and green != red and green != blue:
            #print("     Player rating is greenish!")
            red = pyautogui.pixel(green_x, green_y)[0]
            green =  pyautogui.pixel(green_x, green_y)[1]
            blue =  pyautogui.pixel(green_x, green_y)[2]
            print(f"R:{red} G:{green} B:{blue}")
            green_counter += 1
            if pyautogui.pixel(test_x, test_y) == (255,255,255):
                my_praise_click()
                continue
                
        green_x += 1
        #print(f"i:{i} green test j:{j}")
        #if green_counter > 5:
            #print("We have green count > 5")
            
    praise_button_available = False    
    if pyautogui.pixel(test_x, test_y) == (255,255,255):
        #print("Praise button available")
        praise_button_available = True
    else:
        pass
        #print("No praise button")
    if praise_button_available and green_counter > 3:
        print("Praise button and green counter exceeding 5")
        my_praise_click()
    print("*" * 15)
    player_y += y_iter
    new_move = (player_x, player_y)
    my_move(new_move)
    my_click()
    # check if Praise is available
    ## there print "Praise" is there!
    ## move down
    # if not, just click down
    # Push down arrow
    #pyautogui.press('down')

# %%
# To display mouse position
pyautogui.displayMousePosition() = foo
print(foo)

# %%
def orientate():
    # Training area setup
    time.sleep(5)

    # Navigate to Training Menu
    my_move(training_menu)
    my_click()

    # Click on Individual Training
    time.sleep(2)
    my_move(indy_training_area)
    my_click()

# %%
#time.sleep(10)
time.sleep(7)
#orientate()
#first_player_button = (1307, 412)
first_player_button = (1267, 385)
my_move(first_player_button)
my_click()


def my_praise_click():
    my_move(top_right_praise_button)
    my_click()
    # Click 1st praise choice
    my_move(praise_button)
    my_click()
    # End chat 
    my_move(end_qc_top_right)
    my_click()

def praise_button_exists(button):
    x, y = button
    return pyautogui.pixel(x, y) == (255,255,255)
    
def click_praise_button():
    my_move(top_right_praise_button)
    my_click()
    # Click 1st praise choice
    my_move(praise_button)
    my_click()
    # End chat 
    my_move(end_qc_top_right)
    my_click()

    
#player_x, player_y = first_player_area
#player_x, player_y = (1312, 422)
# Starting position of first player
#player_x, player_y = (1307, 412)
# Nave method


for i in range(players_to_praise):
    if praise_button_exists(top_right_praise_button):
        print("Praise is there")
        time.sleep(2)
        click_praise_button()
        # Asses the rating color
    pyautogui.press('down')
    print(f"Iteration is {i}")

    # Push down arrow
    #pyautogui.press('down')

# %%
import tkinter as tk

# Get the text widget
text_widget = tk.Text()

# Get the cursor position
cursor_position = text_widget.index("insert")

# Print the cursor position
print("The cursor position is {}".format(cursor_position))
# Out:
# The cursor position is 1.0

# %%
    if praise_button_exists:
        # Asses the rating color
        click_praise_button()
        print("Pressing down arrow after clicking praise")
        pyautogui.press('down')
    else:
        my_click()
        print("Pressing down after failing white pixel test")
        pyautogui.press('down')
        continue
    print("Pressing down default")

# %%
from pyautogui import *
import pyautogui
import time
import keyboard
import numpy as np
import random

# GLOBALS
training_menu = (130, 636)
indy_training_area = (1271, 162)
first_player_area = (1267, 405)
#top_right_praise_button = (3488, 261)
top_right_praise_button = (3505,255)
#praise_button = (1809, 1102)
praise_button = (1862, 1102)
#end_qc_top_right = (2690, 382)
end_qc_top_right = (2681, 388)
hover_duration = 0.1
players_to_praise = 65 # Does 22 players total
y_iter = 89


# Define separate move and click functions
def my_move(coord_tuple):
    x, y = coord_tuple
    pyautogui.moveTo(x, y, duration=hover_duration)


def my_click():
    pyautogui.mouseDown()
    #time.sleep(0.1)
    pyautogui.mouseUp()

    
def orientate():
    # Training area setup
    time.sleep(5)

    # Navigate to Training Menu
    my_move(training_menu)
    my_click()

    # Click on Individual Training
    time.sleep(2)
    my_move(indy_training_area)
    my_click()


# To display mouse position
# pyautogui.displayMousePosition()


def my_praise_click():
    my_move(top_right_praise_button)
    my_click()
    # Click 1st praise choice
    my_move(praise_button)
    my_click()
    # End chat 
    my_move(end_qc_top_right)
    my_click()

    
def praise_button_exists(button):
    x, y = button
    return pyautogui.pixel(x, y) == (255,255,255)


def click_praise_buttons():
    my_move(top_right_praise_button)
    my_click()
    # Click 1st praise choice
    my_move(praise_button)
    my_click()
    # End chat 
    my_move(end_qc_top_right)
    my_click()


if __name__ == "__main__":
    # Provide time to move alt-tab to app
    time.sleep(5)
    # Go to Training>Indivdual menus
    orientate()

    # Set first position on first player and mouse click
    first_player_button = (1267, 385)
    my_move(first_player_button)
    my_click()
    
    for i in range(players_to_praise):
        if praise_button_exists(top_right_praise_button):
            print("Praise is there")
            #time.sleep(2)
            click_praise_buttons()
        pyautogui.press('down')
        #print(f"Iteration is {i}")
# Out:
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there
# Praise is there

# %%
# !pip install pyautogui
# !pip install pytesseract
# !pip install tesseract
# !pip install tesseract-ocr
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyautogui in c:\users\lover\appdata\roaming\python\python311\site-packages (0.9.54)
# Requirement already satisfied: pymsgbox in c:\users\lover\appdata\roaming\python\python311\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\lover\appdata\roaming\python\python311\site-packages (from pyautogui) (1.0.7)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\lover\appdata\roaming\python\python311\site-packages (from pyautogui) (0.1.29)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\lover\appdata\roaming\python\python311\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\lover\appdata\roaming\python\python311\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\lover\appdata\roaming\python\python311\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyscreenshot in c:\users\lover\appdata\roaming\python\python311\site-packages (from pyscreeze>=0.1.21->pyautogui) (3.1)
# Requirement already satisfied: Pillow>=9.3.0 in c:\programdata\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (9.4.0)
# Requirement already satisfied: pyperclip in c:\users\lover\appdata\roaming\python\python311\site-packages (from mouseinfo->pyautogui) (1.8.2)
# Requirement already satisfied: EasyProcess in c:\users\lover\appdata\roaming\python\python311\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: entrypoint2 in c:\users\lover\appdata\roaming\python\python311\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: mss in c:\users\lover\appdata\roaming\python\python311\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (9.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytesseract in c:\users\lover\appdata\roaming\python\python311\site-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in c:\programdata\anaconda3\lib\site-packages (from pytesseract) (23.1)
# Requirement already satisfied: Pillow>=8.0.0 in c:\programdata\anaconda3\lib\site-packages (from pytesseract) (9.4.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tesseract in c:\users\lover\appdata\roaming\python\python311\site-packages (0.1.3)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tesseract-ocr
#   Downloading tesseract-ocr-0.0.1.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cython (from tesseract-ocr)
#   Obtaining dependency information for cython from https://files.pythonhosted.org/packages/30/ca/d68432adc1bf90b450c4d9aaf7cbadae50bca0cad1686b1976498abe2eca/Cython-3.0.5-cp311-cp311-win_amd64.whl.metadata
#   Downloading Cython-3.0.5-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Downloading Cython-3.0.5-cp311-cp311-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#     --------------------------------------- 0.1/2.8 MB 1.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.3/2.8 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 22.2 MB/s eta 0:00:00
# Building wheels for collected packages: tesseract-ocr
#   Building wheel for tesseract-ocr (setup.py): started
#   Building wheel for tesseract-ocr (setup.py): finished with status 'error'
#   Running setup.py clean for tesseract-ocr
# Failed to build tesseract-ocr
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [23 lines of output]
#   C:\ProgramData\anaconda3\Lib\site-packages\setuptools\dist.py:745: SetuptoolsDeprecationWarning: Invalid dash-separated options
#   !!
#
#           ********************************************************************************
#           Usage of dash-separated 'description-file' will not be supported in future
#           versions. Please use the underscore name 'description_file' instead.
#
#           This deprecation is overdue, please update your project and remove deprecated
#           calls to avoid build errors in the future.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     opt = self.warn_dash_deprecation(opt, section)
#   running bdist_wheel
#   running build
#   running build_py
#   file tesseract_ocr.py (for module tesseract_ocr) not found
#   file tesseract_ocr.py (for module tesseract_ocr) not found
#   running build_ext
#   building 'tesseract_ocr' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tesseract-ocr
# ERROR: Could not build wheels for tesseract-ocr, which is required to install pyproject.toml-based projects

# %%
#pytesseract.pytesseract.tesseract_cmd = "C:\\Users\\lover\\AppData\\Roaming\\Python\\Python311\\Scripts\\pytesseract"  # your path may be different
#c = get_config()
#c.InteractiveShellApp.exec_lines = [
#'import sys; sys.path.append("C:\\Users\\lover\\AppData\\Roaming\\Python\\Python311\\Scripts\\")']

# %%
#import sys
#sys.path.append("C:\\Users\\lover\\AppData\\Roaming\\Python\\Python311\\Scripts\\")

import sys
sys.path.append("C:/Users/lover/AppData/Roaming/Python/Python311/Scripts/")
sys.path.append("C:/Users/lover/AppData/Roaming/Python/Python39/Scripts/")
sys.path.append("C:/Program Files/Tesseract-OCR/")
# Follow directions to try to add pytesseract to system path
# https://stackoverflow.com/questions/15137985/how-to-add-directory-to-sys-path-on-ipython-startup
# 
# 1. ipython profile create
# 
# 2. ipython locate
# 
# 3. Edit the 'ipython_config' file and add the following:

#c.InteractiveShellApp.exec_lines = ['import sys; sys.path.append("C:/Users/lover/AppData/Roaming/Python/Python311/Scripts/")']

# See this for tessaract nigthmare
#https://stackoverflow.com/questions/50951955/pytesseract-tesseractnotfound-error-tesseract-is-not-installed-or-its-not-i

# %%
# Ran these manually in iPython
#pytesseract.pytesseract.tesseract_cmd = "C://Program Files//Tesseract-OCR//tesseract.exe"
#screenshot = pyautogui.screenshot()
#text = image_to_string(screenshot)
#text
#history

def take_full_screenshot():
    time.sleep(5)
    screenshot = pyautogui.screenshot()
    text = image_to_string(screenshot) 
    print(text)

home_stats_x, home_stats_y = 42, 214
origin_point = 196, 214

home_stats_top_right_x, home_stats_top_right_y = 1208, 212
home_stats_bottom_right_x, home_stats_bottom_right = 1208, 1351
home_stats_boundary_point = 1208, 1351

def calc_width_and_height(origin_point, boundary_point):
    x, y = origin_point
    boundary_x, boundary_y = boundary_point
    return ((boundary_x - x), (boundary_y - y))
    

def take_home_match_screenshot(origin, boundary):
    x, y = origin
    width, height = calc_width_and_height(origin, boundary)
    time.sleep(5)
    print(f"{x}, {y}, {width}, {height}")
    screenshot = pyautogui.screenshot(region=(x, y, width, height))
    text = image_to_string(screenshot) 
    print(text)

# %%
take_home_match_screenshot(origin_point, home_stats_boundary_point)
# Out:
# 196, 214, 1012, 1137
# NAME
#
# A Antonio Rajié
#
# A Kristijan Medié
# Dominik Braun
# Ivan Cvetko
# Damir Zuti¢
# Tomislav Duvnjak
# Tin Andre Tolié
# Vito Caié
#
# Tin Miljak
#
# Toni Majic
#
# Ivor Ljubanovié
# Stjepan Salapic
# Marin Mamut
# Marko Ivan GaSparac
# Filip MiSkié
#
# Ante Matic
#
# Daniel Klari¢
#
# >DdFF PAIFDIVAdA>Fdtd Dd D
#
# Tin Kulenovié
#
# CON
#
# €e€eeeeeeeese segs é
#
# SHP
#
# RAT
#
# 6.7
#
# 6.7
#
# 6.7
#
# GLS
#
# XG AST KEY
#
# 00 - -
#
# 00 - 1
#
# 00 - -
#
# 00 - -
#
# Ol - 1
#
# 00 - -
#
# 00 1 2
#
# 00 1 4
#
# 03 - 1
#
# 1:
#
# 00 - -
#
# 00 - -
#
# 00 - -
#
# 00 - -
#
# 0.0 - -
#
# RUN
# 2.3mi
# 5.7mi
# 4.9mi
# 6.0mi
# 7.2mi
# 3.6mi
# 71Ami
# 5.6mi
# 7.2mi
# 5.7mi
# 6.7mi
# 1.5mi
# 1.5mi
#
# 1.8mi
#
# 3.4mi
#
# 1.8mi

# %%
# We will try to use CHATGPT code to read Normal Name and UUID from game
# We will need to locate click locations using 
# # To display mouse position
# pyautogui.displayMousePosition()


import pyautogui
import pandas as pd
import time
from pytesseract import image_to_string
import pytesseract
import re
import time

pytesseract.pytesseract.tesseract_cmd = "C://Program Files//Tesseract-OCR//tesseract.exe"

# Load your CSV
#df = pd.read_csv('players.csv')
# %store -r df 

#df = pd.DataFrame(df)

# Home coordinates for top left of search bar
coord_x = 484
coord_y = 31

player_profile_coord_x = 167
player_profile_coord_y = 475

(name_region_x, name_region_y) = (484, 31)

(name_region_bottom_right_x, name_region_bottom_right_y) = (2645, 109)

(width, height) = ((name_region_bottom_right_x - name_region_x), 
                   (name_region_bottom_right_y - name_region_y))

# Function to search for player and extract information
def search_player_and_extract_info(player_name):
    # Navigate to the search interface (you'll need to find the exact coordinates)
    pyautogui.click(x=coord_x, y=coord_y)
    time.sleep(2)  # Wait for the interface to open
    #return
    # Enter the player's name
    pyautogui.write(player_name)
    pyautogui.press('enter')
    time.sleep(2)  # Wait for the search results
    #return

    # Click on the player profile (you may need to adjust coordinates or use image recognition)
    pyautogui.click(x=player_profile_coord_x, y=player_profile_coord_y)
    time.sleep(2)  # Wait for the profile to open
    #return
    
    # Take a screenshot and use OCR to extract the short name and UUID
    # Adjust the region to where the short name and UUID would be
    #print("our region is")
    #print((name_region_x, name_region_y, width, height))
    #print()
    screenshot = pyautogui.screenshot(region=(name_region_x, name_region_y, width, height))
    text = image_to_string(screenshot)
    short_name, uuid = extract_name_and_id(text)
    #print(f"Short Name:{short_name}\nUUID:{uuid}")
    #return
    # print(f"Text we see: {text}")
    # print("----")
    # print("try to see hidden chars")
    # print( [text] )
    # print("----")
    # print("Try using repr")
    # print( repr(text) )
    # player_text_data = text.split("\n")
    # return
    
    # Parse the extracted text to find the short name and UUID
    # This step depends on how the OCR text is formatted
    #short_name = 'extracted_short_name'  # Placeholder
    #uuid = 'extracted_uuid'  # Placeholder

    return short_name, uuid


def extract_uuid(input_string):
    match = re.search(r'\(ID:(\d+)\)', input_string)
    if match:
        return match.group(1)
    else:
        return None

def process_uuid_elements(player_data):
    for string in [player_data[2], player_data[1]]:
        output = extract_uuid(string)
        if output:
            return output
    return None
    
def extract_name_and_id(player_data):
    # Split player data on "\n"
    player_data_list = player_data.split("\n")
    
    # The length of all lists will be three. Check final element is null
    if re.match("Q ", player_data_list[0]):
        # print(f"2nd element {player_data_list[1]}")
        # print(f"3rd element {player_data_list[2]}")
        #print("Player is Club player")
        short_name_unclean = player_data_list[0]
        #print(f"We found {short_name_unclean}")
        short_name = short_name_unclean.split(".")[1].lstrip()
        #short_name = player_data_list[0]
    else:
        # We have a player at a club
        #print("Player is Free Agent")
        short_name = player_data_list[0]
     
    #print( repr(short_name) )
    # Now that we have the name we must CLEANSE IT IN FIRE!
    short_name = re.sub(r'^.*?\d+\.\s*', "", short_name)
    #print(f"FINAL Short Name: {short_name}")
        
    # UUID should be third or second element, go "upwards" to locate
    uuid = process_uuid_elements(player_data_list)
    return (short_name, uuid)

              
iterate_count = 0
unchanged_list = []

if __name__ == "__main__":
    # Provide time to move alt-tab to app
    time.sleep(5)
    # Go to Training>Indivdual menus
    #orientate()

    # Load your CSV
    #df = pd.read_csv('players_small.csv')
    start_time = time.time()
    # Loop over the dataframe
    # We can also reuse/change our start point
    #last_valid_index = df['short name'].last_valid_index()
    #for index, row in df.loc[last_valid_index+1].iterrows():
    #for index, row in df.iterrows(): # Originial
    for index, row in df.items
        try:
            player_name = row['Name']
            #print(f"Player Name: {player_name}")
            short_name, uuid = search_player_and_extract_info(player_name)

            # Update the dataframe
            df.at[index, 'short name'] = short_name
            df.at[index, 'UUID'] = uuid

            # Go back to the main screen or search screen before next iteration
            # This might involve pressing 'esc' or clicking a 'back' button
            pyautogui.press('esc')
        except IndexError:
            #print(f"Unable to locate: {player_name} in your db") 
            unchanged_list.append(player_name)
        
        iterate_count +=1

    # Write the updated dataframe back to CSV
    df.to_csv('players_updated.csv', index=False)
    
    end_time = time.time()
    total_time = end_time - start_time
              
    print(f"Total time: {total_time}")
    print(f"Time per iteration: {total_time/iterate_count}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38160\1105214794.py in ?()
#     135     start_time = time.time()
#     136     # Loop over the dataframe
#     137     # We can also reuse/change our start point
#     138     last_valid_index = df['short name'].last_valid_index()
# --> 139     for index, row in df.loc[last_valid_index+1].iterrows():
#     140     #for index, row in df.iterrows(): # Originial
#     141         try:
#     142             player_name = row['Name']
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'iterrows'

# %%
store -r df

# %%
df
# Out:
#                                                Name   CA   PA  PA Min  PA Max  \
# 0                       Lamine Yamal Nasraoui Ebana  125  -10     170     200
# 1                          Alejandro Balde Martínez  154  -95     160     190
# 2                             Anssumane Fati Vieira  148  -95     160     190
# 3                   Endrick Felipe Moreira de Sousa  114  -95     160     190
# 4     Estêvão Willian Almeida de Oliveira Gonçalves   75  -95     160     190
# ...                                             ...  ...  ...     ...     ...
# 7124                                  Yusuf Özdemir  115  130     130     130
# 7125                                Zakaria El Ayeb   96  130     130     130
# 7126                    Zakaria Seraj Ahmed Hawsawi  115  130     130     130
# 7127                               Zeno Ibsen Rossi   94  130     130     130
# 7128                                   Zied Berrima   93  130     130     130
#
#                                short name        UUID
# 0                            Lamine Yamal  2000256231
# 1                         Alejandro Balde    67296654
# 2                               Ansu Fati    67276122
# 3                                 Endrick        None
# 4     Q, Game: "Bangoche FM - NK Sesvete"        None
# ...                                   ...         ...
# 7124                                  NaN         NaN
# 7125                                  NaN         NaN
# 7126                                  NaN         NaN
# 7127                                  NaN         NaN
# 7128                                  NaN         NaN
#
# [7129 rows x 7 columns]

# %%
last_valid_index = df['short name'].last_valid_index()
print(last_valid_index)
# df
# Out:
# 6171

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)

# %%
for row, index in df.iterrows():
    print(f"Row:{row} index:{index}")
# Out:
# Row:0 index:Name          Lamine Yamal Nasraoui Ebana
# CA                                    125
# PA                                    -10
# PA Min                                170
# PA Max                                200
# short name                   Lamine Yamal
# UUID                           2000256231
# Name: 0, dtype: object
# Row:1 index:Name          Alejandro Balde Martínez
# CA                                 154
# PA                                 -95
# PA Min                             160
# PA Max                             190
# short name             Alejandro Balde
# UUID                          67296654
# Name: 1, dtype: object
# Row:2 index:Name          Anssumane Fati Vieira
# CA                              148
# PA                              -95
# PA Min                          160
# PA Max                          190
# short name                Ansu Fati
# UUID                       67276122
# Name: 2, dtype: object
# Row:3 index:Name          Endrick Felipe Moreira de Sousa
# CA                                        114
# PA                                        -95
# PA Min                                    160
# PA Max                                    190
# short name                            Endrick
# UUID                                     None
# Name: 3, dtype: object
# Row:4 index:Name          Estêvão Willian Almeida de Oliveira Gonçalves
# CA                                                       75
# PA                                                      -95
# PA Min                                                  160
# PA Max                                                  190
# short name              Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                                   None
# Name: 4, dtype: object
# Row:5 index:Name          Evan Joe Ferguson
# CA                          138
# PA                          -95
# PA Min                      160
# PA Max                      190
# short name        Evan Ferguson
# UUID                       None
# Name: 5, dtype: object
# Row:6 index:Name          Mikey Moore
# CA                     91
# PA                    -95
# PA Min                160
# PA Max                190
# short name            NaN
# UUID                  NaN
# Name: 6, dtype: object
# Row:7 index:Name          Pablo Martín Páez Gavira
# CA                                 154
# PA                                 -95
# PA Min                             160
# PA Max                             190
# short name                        Gavi
# UUID                        2000049413
# Name: 7, dtype: object
# Row:8 index:Name          Vitor Hugo Roque Ferreira
# CA                                  132
# PA                                  -95
# PA Min                              160
# PA Max                              190
# short name                  Vitor Roque
# UUID                         2000095783
# Name: 8, dtype: object
# Row:9 index:Name          Warren Zaïre-Emery
# CA                           136
# PA                           -95
# PA Min                       160
# PA Max                       190
# short name    Warren Zaire-Emery
# UUID                        None
# Name: 9, dtype: object
# Row:10 index:Name          Youssoufa Moukoko
# CA                          125
# PA                          -95
# PA Min                      160
# PA Max                      190
# short name    Youssoufa Moukoko
# UUID                 2000074825
# Name: 10, dtype: object
# Row:11 index:Name          Jude Victor William Bellingham
# CA                                       168
# PA                                       188
# PA Min                                   188
# PA Max                                   188
# short name                   Jude Bellingham
# UUID                                    None
# Name: 11, dtype: object
# Row:12 index:Name          Bukayo Ayoyinka Saka
# CA                             173
# PA                             186
# PA Min                         186
# PA Max                         186
# short name             Bukayo Saka
# UUID                          None
# Name: 12, dtype: object
# Row:13 index:Name          Jamal Musiala
# CA                      157
# PA                      185
# PA Min                  185
# PA Max                  185
# short name    Jamal Musiala
# UUID               28124579
# Name: 13, dtype: object
# Row:14 index:Name          Moisés Isaac Caicedo Corozo
# CA                                    156
# PA                                    185
# PA Min                                185
# PA Max                                185
# short name                 Moisés Caicedo
# UUID                             86078360
# Name: 14, dtype: object
# Row:15 index:Name          William Saliba
# CA                       164
# PA                       182
# PA Min                   182
# PA Max                   182
# short name    William Saliba
# UUID                49039004
# Name: 15, dtype: object
# Row:16 index:Name          Alejandro Garnacho Ferreyra
# CA                                    142
# PA                                     -9
# PA Min                                150
# PA Max                                180
# short name             Alejandro Garnacho
# UUID                                 None
# Name: 16, dtype: object
# Row:17 index:Name          Alex Jay Scott
# CA                       132
# PA                        -9
# PA Min                   150
# PA Max                   180
# short name        Alex Scott
# UUID                    None
# Name: 17, dtype: object
# Row:18 index:Name          Ângelo Gabriel Borges Damaceno
# CA                                       123
# PA                                        -9
# PA Min                                   150
# PA Max                                   180
# short name                            Angelo
# UUID                                    None
# Name: 18, dtype: object
# Row:19 index:Name          António João Pereira Albuquerque Tavares Silva
# CA                                                       142
# PA                                                        -9
# PA Min                                                   150
# PA Max                                                   180
# short name                                     Antonio Silva
# UUID                                                83320135
# Name: 19, dtype: object
# Row:20 index:Name          Archie Gray
# CA                    117
# PA                     -9
# PA Min                150
# PA Max                180
# short name    Archie Gray
# UUID           2000182795
# Name: 20, dtype: object
# Row:21 index:Name           Arda Güler
# CA                    125
# PA                     -9
# PA Min                150
# PA Max                180
# short name    Aleix Vidal
# UUID             67064771
# Name: 21, dtype: object
# Row:22 index:Name          Badredine Bouanani
# CA                           115
# PA                            -9
# PA Min                       150
# PA Max                       180
# short name    Badredine Bouanani
# UUID                  2000100062
# Name: 22, dtype: object
# Row:23 index:Name          Ben Gannon Doak
# CA                        115
# PA                         -9
# PA Min                    150
# PA Max                    180
# short name           Ben Doak
# UUID                     None
# Name: 23, dtype: object
# Row:24 index:Name          Benjamin Šeško
# CA                       135
# PA                        -9
# PA Min                   150
# PA Max                   180
# short name          Ben Amos
# UUID                28000902
# Name: 24, dtype: object
# Row:25 index:Name          Carlos Noom Quomah Baleba
# CA                                  130
# PA                                   -9
# PA Min                              150
# PA Max                              180
# short name                Carlos Baleba
# UUID                         2000166563
# Name: 25, dtype: object
# Row:26 index:Name          Cesare Casadei
# CA                       123
# PA                        -9
# PA Min                   150
# PA Max                   180
# short name    Cesare Casadei
# UUID                43500064
# Name: 26, dtype: object
# Row:27 index:Name          Claudio Jeremías Echeverri
# CA                                   107
# PA                                    -9
# PA Min                               150
# PA Max                               180
# short name             Claudio Echeverri
# UUID                          2000094152
# Name: 27, dtype: object
# Row:28 index:Name                                  Désiré Doué
# CA                                            122
# PA                                             -9
# PA Min                                        150
# PA Max                                        180
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 28, dtype: object
# Row:29 index:Name          Eduardo Celmi Camavinga
# CA                                165
# PA                                180
# PA Min                            180
# PA Max                            180
# short name          Eduardo Camavinga
# UUID                         49056243
# Name: 29, dtype: object
# Row:30 index:Name          Eli Junior Eric Anat Kroupi
# CA                                    110
# PA                                     -9
# PA Min                                150
# PA Max                                180
# short name                  Junior Kroupi
# UUID                           2000181790
# Name: 30, dtype: object
# Row:31 index:Name          Eliesse Ben Seghir
# CA                           121
# PA                            -9
# PA Min                       150
# PA Max                       180
# short name    Eliesse Ben Seghir
# UUID                  2000104892
# Name: 31, dtype: object
# Row:32 index:Name          Ethan Chidiebere Nwaneri
# CA                                 115
# PA                                  -9
# PA Min                             150
# PA Max                             180
# short name               Ethan Nwaneri
# UUID                        2000283271
# Name: 32, dtype: object
# Row:33 index:Name          Florian Richard Wirtz
# CA                              148
# PA                               -9
# PA Min                          150
# PA Max                          180
# short name            Florian Wirtz
# UUID                       91193048
# Name: 33, dtype: object
# Row:34 index:Name          Forzan Assan Ouédraogo
# CA                               103
# PA                                -9
# PA Min                           150
# PA Max                           180
# short name           Assan Ouédraogo
# UUID                      2000188173
# Name: 34, dtype: object
# Row:35 index:Name          Gabriel Teodoro Martinelli Silva
# CA                                         160
# PA                                         180
# PA Min                                     180
# PA Max                                     180
# short name                  Gabriel Martinelli
# UUID                                      None
# Name: 35, dtype: object
# Row:36 index:Name          Guillaume Restes
# CA                         120
# PA                          -9
# PA Min                     150
# PA Max                     180
# short name    Guillaume Restes
# UUID                2000094715
# Name: 36, dtype: object
# Row:37 index:Name          Iván Fresneda Corraliza
# CA                                132
# PA                                 -9
# PA Min                            150
# PA Max                            180
# short name              Ivan Fresneda
# UUID                       2000165653
# Name: 37, dtype: object
# Row:38 index:Name          João Miguel Fins Veloso
# CA                                102
# PA                                 -9
# PA Min                            150
# PA Max                            180
# short name                Joao Veloso
# UUID                       2000131486
# Name: 38, dtype: object
# Row:39 index:Name          João Pedro Gonçalves Neves
# CA                                   139
# PA                                    -9
# PA Min                               150
# PA Max                               180
# short name                    Joao Neves
# UUID                          2000030130
# Name: 39, dtype: object
# Row:40 index:Name          João Pedro Seno Luís Rêgo
# CA                                  100
# PA                                   -9
# PA Min                              150
# PA Max                              180
# short name                    Joao Régo
# UUID                               None
# Name: 40, dtype: object
# Row:41 index:Name          Jorrel Hato
# CA                    123
# PA                     -9
# PA Min                150
# PA Max                180
# short name    Jorrel Hato
# UUID           2000105654
# Name: 41, dtype: object
# Row:42 index:Name          Julien Duranville
# CA                          113
# PA                           -9
# PA Min                      150
# PA Max                      180
# short name    Julien Duranville
# UUID                 2000155483
# Name: 42, dtype: object
# Row:43 index:Name          Junior Castello Lukeba
# CA                               138
# PA                                -9
# PA Min                           150
# PA Max                           180
# short name           Castello Lukeba
# UUID                            None
# Name: 43, dtype: object
# Row:44 index:Name          Karim Konaté
# CA                     128
# PA                      -9
# PA Min                 150
# PA Max                 180
# short name    Karim Konaté
# UUID                  None
# Name: 44, dtype: object
# Row:45 index:Name          Lorran Lucas Pereira de Sousa
# CA                                      105
# PA                                       -9
# PA Min                                  150
# PA Max                                  180
# short name                           Lorran
# UUID                             2000241678
# Name: 45, dtype: object
# Row:46 index:Name          Luís Guilherme Lira dos Santos
# CA                                       108
# PA                                        -9
# PA Min                                   150
# PA Max                                   180
# short name                    Luis Guilherme
# UUID                              2000221458
# Name: 46, dtype: object
# Row:47 index:Name          Marcos Leonardo Santos Almeira
# CA                                       130
# PA                                        -9
# PA Min                                   150
# PA Max                                   180
# short name                   Marcos Leonardo
# UUID                                19380666
# Name: 47, dtype: object
# Row:48 index:Name          Mathys Tel
# CA                   130
# PA                    -9
# PA Min               150
# PA Max               180
# short name    Mathys Tel
# UUID          2000104850
# Name: 48, dtype: object
# Row:49 index:Name          Michael Olabode Kayode
# CA                               125
# PA                                -9
# PA Min                           150
# PA Max                           180
# short name            Michael Kayode
# UUID                            None
# Name: 49, dtype: object
# Row:50 index:Name          Mohamed-Ali Cho
# CA                        120
# PA                         -9
# PA Min                    150
# PA Max                    180
# short name    Mohamed-Ali Cho
# UUID               2000006280
# Name: 50, dtype: object
# Row:51 index:Name          Noah Darvich
# CA                     100
# PA                      -9
# PA Min                 150
# PA Max                 180
# short name    Noah Darvich
# UUID            2000257651
# Name: 51, dtype: object
# Row:52 index:Name          Oscar Gloukh
# CA                     124
# PA                      -9
# PA Min                 150
# PA Max                 180
# short name    Oscar Gloukh
# UUID                  None
# Name: 52, dtype: object
# Row:53 index:Name          Ousmane Diomande
# CA                         142
# PA                          -9
# PA Min                     150
# PA Max                     180
# short name    Ousmane Diomande
# UUID                2000160511
# Name: 53, dtype: object
# Row:54 index:Name          Paul Wanner
# CA                    106
# PA                     -9
# PA Min                150
# PA Max                180
# short name    Paul Wanner
# UUID           2000138516
# Name: 54, dtype: object
# Row:55 index:Name          Rasmus Winther Højlund
# CA                               142
# PA                                -9
# PA Min                           150
# PA Max                           180
# short name            Rasmus Hgjlund
# UUID                            None
# Name: 55, dtype: object
# Row:56 index:Name          Ray Kendry Páez Andrade
# CA                                110
# PA                                 -9
# PA Min                            150
# PA Max                            180
# short name                Kendry Paez
# UUID                       2000252303
# Name: 56, dtype: object
# Row:57 index:Name          Rayan Mathis Cherki
# CA                            128
# PA                             -9
# PA Min                        150
# PA Max                        180
# short name           Rayan Cherki
# UUID                     49056279
# Name: 57, dtype: object
# Row:58 index:Name          Rodrigo Duarte Ribeiro
# CA                                96
# PA                                -9
# PA Min                           150
# PA Max                           180
# short name           Rodrigo Ribeiro
# UUID                      2000104450
# Name: 58, dtype: object
# Row:59 index:Name          Rodrigo Mora Carvalho
# CA                               85
# PA                               -9
# PA Min                          150
# PA Max                          180
# short name             Rodrigo Mora
# UUID                     2000265865
# Name: 59, dtype: object
# Row:60 index:Name            Roméo Lavia
# CA                      134
# PA                       -9
# PA Min                  150
# PA Max                  180
# short name    Joao Palhinha
# UUID               55070285
# Name: 60, dtype: object
# Row:61 index:Name          Samuel Iling-Junior
# CA                            133
# PA                             -9
# PA Min                        150
# PA Max                        180
# short name           Samuel lling
# UUID                         None
# Name: 61, dtype: object
# Row:62 index:Name          Shaqueel van Persie
# CA                            100
# PA                             -9
# PA Min                        150
# PA Max                        180
# short name    Shaqueel van Persie
# UUID                   2000177913
# Name: 62, dtype: object
# Row:63 index:Name          Shea Lacey
# CA                    80
# PA                    -9
# PA Min               150
# PA Max               180
# short name    Shea Lacey
# UUID                None
# Name: 63, dtype: object
# Row:64 index:Name          Simone Pafundi
# CA                       111
# PA                        -9
# PA Min                   150
# PA Max                   180
# short name    Simone Pafundi
# UUID              2000178997
# Name: 64, dtype: object
# Row:65 index:Name                    Stefan Bajčetić Maquieira
# CA                                            120
# PA                                             -9
# PA Min                                        150
# PA Max                                        180
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 65, dtype: object
# Row:66 index:Name          Sverre Halseth Nypan
# CA                             115
# PA                              -9
# PA Min                         150
# PA Max                         180
# short name    Sverre Halseth Nypan
# UUID                    2000254793
# Name: 66, dtype: object
# Row:67 index:Name          Tommaso Baldanzi
# CA                         129
# PA                          -9
# PA Min                     150
# PA Max                     180
# short name    Tommaso Baldanzi
# UUID                      None
# Name: 67, dtype: object
# Row:68 index:Name          Valentín Barco
# CA                       130
# PA                        -9
# PA Min                   150
# PA Max                   180
# short name    Valentin Barco
# UUID              2000033291
# Name: 68, dtype: object
# Row:69 index:Name          Valentino Francisco Livramento
# CA                                       134
# PA                                        -9
# PA Min                                   150
# PA Max                                   180
# short name                   Tino Livramento
# UUID                                28124569
# Name: 69, dtype: object
# Row:70 index:Name          Wesley Fofana
# CA                      151
# PA                      180
# PA Min                  180
# PA Max                  180
# short name    Wesley Fofana
# UUID               49037900
# Name: 70, dtype: object
# Row:71 index:Name          Xavi Quentin Shay Simons
# CA                                 148
# PA                                  -9
# PA Min                             150
# PA Max                             180
# short name                 Xavi Simons
# UUID                          67288555
# Name: 71, dtype: object
# Row:72 index:Name          Yaser Esneider Asprilla Martínez
# CA                                         125
# PA                                          -9
# PA Min                                     150
# PA Max                                     180
# short name                      Yaser Asprilla
# UUID                                2000053239
# Name: 72, dtype: object
# Row:73 index:Name          Joško Gvardiol
# CA                       148
# PA                       178
# PA Min                   178
# PA Max                   178
# short name    JoSko Gvardiol
# UUID                24060473
# Name: 73, dtype: object
# Row:74 index:Name          Rodrygo Silva de Goes
# CA                              164
# PA                              178
# PA Min                          178
# PA Max                          178
# short name                  Rodrygo
# UUID                       19306929
# Name: 74, dtype: object
# Row:75 index:Name          Khvicha Kvaratskhelia
# CA                              164
# PA                              177
# PA Min                          177
# PA Max                          177
# short name    Khvicha Kvaratskhelia
# UUID                       59130638
# Name: 75, dtype: object
# Row:76 index:Name          Nuno Alexandre Tavares Mendes
# CA                                      152
# PA                                      177
# PA Min                                  177
# PA Max                                  177
# short name                      Nuno Mendes
# UUID                                   None
# Name: 76, dtype: object
# Row:77 index:Name          Pedro González López
# CA                             162
# PA                             176
# PA Min                         176
# PA Max                         176
# short name                   Pedri
# UUID                      67293495
# Name: 77, dtype: object
# Row:78 index:Name          Manuel Ugarte Ribeiro
# CA                              152
# PA                              175
# PA Min                          175
# PA Max                          175
# short name            Manuel Ugarte
# UUID                       78084541
# Name: 78, dtype: object
# Row:79 index:Name          Yeremy Jesús Pino Santos
# CA                                 142
# PA                                 175
# PA Min                             175
# PA Max                             175
# short name                 Yeremy Pino
# UUID                          67295650
# Name: 79, dtype: object
# Row:80 index:Name          Enzo Jeremías Fernández
# CA                                158
# PA                                174
# PA Min                            174
# PA Max                            174
# short name             Enzo Fernandez
# UUID                             None
# Name: 80, dtype: object
# Row:81 index:Name                  Jurriën David Norman Timber
# CA                                            148
# PA                                            173
# PA Min                                        173
# PA Max                                        173
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 81, dtype: object
# Row:82 index:Name          Alphonso Boyle Davies
# CA                              156
# PA                              172
# PA Min                          172
# PA Max                          172
# short name          Alphonso Davies
# UUID                       20041862
# Name: 82, dtype: object
# Row:83 index:Name          Nicholas Williams Arthuer
# CA                                  148
# PA                                  171
# PA Min                              171
# PA Max                              171
# short name                Nico Williams
# UUID                           67276230
# Name: 83, dtype: object
# Row:84 index:Name          Adam James Wharton
# CA                           117
# PA                           -85
# PA Min                       140
# PA Max                       170
# short name          Adam Wharton
# UUID                  2000053516
# Name: 84, dtype: object
# Row:85 index:Name                      Afonso Bastardo Moreira
# CA                                            106
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 85, dtype: object
# Row:86 index:Name                         Alan Agustín Velasco
# CA                                            127
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 86, dtype: object
# Row:87 index:Name          Alberto Moleiro González
# CA                                 128
# PA                                 -85
# PA Min                             140
# PA Max                             170
# short name             Alberto Moleiro
# UUID                        2000028320
# Name: 87, dtype: object
# Row:88 index:Name          Alejandro Iturbe Encabo
# CA                                105
# PA                                -85
# PA Min                            140
# PA Max                            170
# short name           Alejandro Iturbe
# UUID                       2000049485
# Name: 88, dtype: object
# Row:89 index:Name          Alejandro Monserrate Pueyo
# CA                                    83
# PA                                   -85
# PA Min                               140
# PA Max                               170
# short name            Q, Jano Monserrate
# UUID                          2000295441
# Name: 89, dtype: object
# Row:90 index:Name          Alfie Dorrington
# CA                         100
# PA                         -85
# PA Min                     140
# PA Max                     170
# short name    Alfie Dorrington
# UUID                2000123637
# Name: 90, dtype: object
# Row:91 index:Name          Alfie Sean Devine
# CA                          106
# PA                          -85
# PA Min                      140
# PA Max                      170
# short name         Alfie Devine
# UUID                       None
# Name: 91, dtype: object
# Row:92 index:Name                Álvaro Daniel Rodríguez Muñoz
# CA                                            119
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 92, dtype: object
# Row:93 index:Name          Amidou Doumbouya
# CA                          75
# PA                         -85
# PA Min                     140
# PA Max                     170
# short name    Amadou Doumbouya
# UUID                      None
# Name: 93, dtype: object
# Row:94 index:Name          Andrey Nascimento dos Santos
# CA                                     124
# PA                                     -85
# PA Min                                 140
# PA Max                                 170
# short name                   Andrey Santos
# UUID                            2000007415
# Name: 94, dtype: object
# Row:95 index:Name                                Antoine Mendy
# CA                                             98
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 95, dtype: object
# Row:96 index:Name                         Antoni-Djibu Milambo
# CA                                            110
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 96, dtype: object
# Row:97 index:Name          Antonio Eromonsele Nordby Nusa
# CA                                       113
# PA                                       -85
# PA Min                                   140
# PA Max                                   170
# short name                      Antonio Nusa
# UUID                              2000090211
# Name: 97, dtype: object
# Row:98 index:Name          Armel Bella-Kotchap
# CA                            134
# PA                            -85
# PA Min                        140
# PA Max                        170
# short name    Armel Bella-Kotchap
# UUID                         None
# Name: 98, dtype: object
# Row:99 index:Name          Arsen Zakharyan
# CA                        126
# PA                        -85
# PA Min                    140
# PA Max                    170
# short name    Arsen Zakharyan
# UUID                     None
# Name: 99, dtype: object
# Row:100 index:Name          Arthur Vermeeren
# CA                         110
# PA                         -85
# PA Min                     140
# PA Max                     170
# short name    Arthur Vermeeren
# UUID                2000127465
# Name: 100, dtype: object
# Row:101 index:Name          Ashley Phillips
# CA                        112
# PA                        -85
# PA Min                    140
# PA Max                    170
# short name    Ashley Phillips
# UUID               2000137635
# Name: 101, dtype: object
# Row:102 index:Name                               Ayanda Sishuba
# CA                                            100
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 102, dtype: object
# Row:103 index:Name           Ayman Kari
# CA                    110
# PA                    -85
# PA Min                140
# PA Max                170
# short name    Malang Sarr
# UUID             48036830
# Name: 103, dtype: object
# Row:104 index:Name                    Bastien Meupiyou Menadjou
# CA                                            104
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 104, dtype: object
# Row:105 index:Name           Bilal El Khannouss
# CA                            120
# PA                            -85
# PA Min                        140
# PA Max                        170
# short name    Bilal El Knhannouss
# UUID                         None
# Name: 105, dtype: object
# Row:106 index:Name          Callum Craig Doyle
# CA                           130
# PA                           -85
# PA Min                       140
# PA Max                       170
# short name          Callum Doyle
# UUID                  2000036812
# Name: 106, dtype: object
# Row:107 index:Name          Carlos Roberto Forbs Borges
# CA                                    125
# PA                                    -85
# PA Min                                140
# PA Max                                170
# short name                  Carlos Borges
# UUID                           2000009057
# Name: 107, dtype: object
# Row:108 index:Name               Carlos Thomás Gómez Montefiori
# CA                                             82
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 108, dtype: object
# Row:109 index:Name          Carney Chukwuemeka
# CA                           125
# PA                           -85
# PA Min                       140
# PA Max                       170
# short name    Carney Chukwuemeka
# UUID                    28127875
# Name: 109, dtype: object
# Row:110 index:Name          Chadi Riad Dnanou
# CA                          125
# PA                          -85
# PA Min                      140
# PA Max                      170
# short name           Chadi Riad
# UUID                       None
# Name: 110, dtype: object
# Row:111 index:Name          Charlie Michael Patino
# CA                               114
# PA                               -85
# PA Min                           140
# PA Max                           170
# short name            Charlie Patino
# UUID                      2000047228
# Name: 111, dtype: object
# Row:112 index:Name          Chris Rigg
# CA                    93
# PA                   -85
# PA Min               140
# PA Max               170
# short name    Chris Rigg
# UUID          2000254692
# Name: 112, dtype: object
# Row:113 index:Name          David Datro Fofana
# CA                           128
# PA                           -85
# PA Min                       140
# PA Max                       170
# short name          Datro Fofana
# UUID                    12092528
# Name: 113, dtype: object
# Row:114 index:Name              David Enmanuel Martínez Morales
# CA                                            104
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 114, dtype: object
# Row:115 index:Name          Dean Donny Huijsen
# CA                            92
# PA                           -85
# PA Min                       140
# PA Max                       170
# short name          Dean Huijsen
# UUID                  2000109240
# Name: 115, dtype: object
# Row:116 index:Name          Deivid Washington de Souza Eugenio
# CA                                           118
# PA                                           -85
# PA Min                                       140
# PA Max                                       170
# short name                     Deivid Washington
# UUID                                  2000206497
# Name: 116, dtype: object
# Row:117 index:Name          Dennis Seimen
# CA                      103
# PA                      -85
# PA Min                  140
# PA Max                  170
# short name              NaN
# UUID                    NaN
# Name: 117, dtype: object
# Row:118 index:Name                           Diego Callai Silva
# CA                                            103
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 118, dtype: object
# Row:119 index:Name          Dijon Kameri
# CA                     121
# PA                     -85
# PA Min                 140
# PA Max                 170
# short name    Dijon Kameri
# UUID              16337074
# Name: 119, dtype: object
# Row:120 index:Name          Dominik Szoboszlai
# CA                           154
# PA                           170
# PA Min                       170
# PA Max                       170
# short name    Dominik Szoboszlai
# UUID                    16202373
# Name: 120, dtype: object
# Row:121 index:Name          El Chadaille Bitshiabu
# CA                               116
# PA                               -85
# PA Min                           140
# PA Max                           170
# short name    El Chadaille Bitshiabu
# UUID                      2000100253
# Name: 121, dtype: object
# Row:122 index:Name          Elliot Anderson
# CA                        127
# PA                        -85
# PA Min                    140
# PA Max                    170
# short name    Elliot Anderson
# UUID                 28127254
# Name: 122, dtype: object
# Row:123 index:Name                         Emanuel Esseh Emegha
# CA                                            129
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 123, dtype: object
# Row:124 index:Name                                  Enzo Molebe
# CA                                             80
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 124, dtype: object
# Row:125 index:Name                                 Enzo Sternal
# CA                                             80
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 125, dtype: object
# Row:126 index:Name          Ernest Appiah Nuamah
# CA                             134
# PA                             -85
# PA Min                         140
# PA Max                         170
# short name           Ernest Nuamah
# UUID                    2000156783
# Name: 126, dtype: object
# Row:127 index:Name                                  Ernest Poku
# CA                                            109
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 127, dtype: object
# Row:128 index:Name          Estanislau Pedrola Fortuny
# CA                                   126
# PA                                   -85
# PA Min                               140
# PA Max                               170
# short name               Estanis Pedrola
# UUID                                None
# Name: 128, dtype: object
# Row:129 index:Name          Ethan Butera
# CA                      99
# PA                     -85
# PA Min                 140
# PA Max                 170
# short name    Rohan Luthra
# UUID              28122947
# Name: 129, dtype: object
# Row:130 index:Name          Fábio Leandro Freitas Gouveia De Carvalho
# CA                                                  132
# PA                                                  -85
# PA Min                                              140
# PA Max                                              170
# short name                               Fabio Carvalho
# UUID                                               None
# Name: 130, dtype: object
# Row:131 index:Name          Facundo Valentín Buonanotte
# CA                                    131
# PA                                    -85
# PA Min                                140
# PA Max                                170
# short name             Facundo Buonanotte
# UUID                                 None
# Name: 131, dtype: object
# Row:132 index:Name          Farès Chaïbi
# CA                     127
# PA                     -85
# PA Min                 140
# PA Max                 170
# short name    Farés Chaibi
# UUID                  None
# Name: 132, dtype: object
# Row:133 index:Name          Faustino Adebola Rasheed Anjorin
# CA                                         117
# PA                                         -85
# PA Min                                     140
# PA Max                                     170
# short name                    Faustino Anjorin
# UUID                                      None
# Name: 133, dtype: object
# Row:134 index:Name          Francesco Pio Esposito
# CA                               111
# PA                               -85
# PA Min                           140
# PA Max                           170
# short name    Francesco Pio Esposito
# UUID                      2000146883
# Name: 134, dtype: object
# Row:135 index:Name                        Gabriël Osei Misehouy
# CA                                            108
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 135, dtype: object
# Row:136 index:Name                        Gabriel Serôdio Silva
# CA                                             75
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 136, dtype: object
# Row:137 index:Name             Gabriel Silva Moscardo de Salles
# CA                                            118
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 137, dtype: object
# Row:138 index:Name          Gaël Lafont
# CA                     81
# PA                    -85
# PA Min                140
# PA Max                170
# short name            NaN
# UUID                  NaN
# Name: 138, dtype: object
# Row:139 index:Name          Giacomo Faticanti
# CA                          100
# PA                          -85
# PA Min                      140
# PA Max                      170
# short name    Giacomo Faticanti
# UUID                 2000024755
# Name: 139, dtype: object
# Row:140 index:Name                    Gianluca Prestianni Gross
# CA                                            114
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 140, dtype: object
# Row:141 index:Name          Giorgio Scalvini
# CA                         145
# PA                         170
# PA Min                     170
# PA Max                     170
# short name    Giorgio Scalvini
# UUID                  43500755
# Name: 141, dtype: object
# Row:142 index:Name             Giovani Henrique Amorim da Silva
# CA                                            107
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 142, dtype: object
# Row:143 index:Name                     Gonçalo Carvalho Moreira
# CA                                             89
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 143, dtype: object
# Row:144 index:Name           Guilherme Mascarenhas Sousa Santos
# CA                                             85
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 144, dtype: object
# Row:145 index:Name          Héctor Fort García
# CA                           100
# PA                           -85
# PA Min                       140
# PA Max                       170
# short name           Héctor Fort
# UUID                  2000227977
# Name: 145, dtype: object
# Row:146 index:Name             Heriberto De Jesus Jurado Flores
# CA                                             92
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 146, dtype: object
# Row:147 index:Name          Hugo Emanuel Larsson
# CA                             123
# PA                             -85
# PA Min                         140
# PA Max                         170
# short name            Hugo Larsson
# UUID                          None
# Name: 147, dtype: object
# Row:148 index:Name                          Hugo Félix Sequeira
# CA                                            103
# PA                                            -85
# PA Min                                        140
# PA Max                                        170
# short name    Q, Game: "Bangoche FM - NK Sesvete"
# UUID                                         None
# Name: 148, dtype: object
# Row:149 index:Name          Iker Villar Mendoza
# CA                             80
# PA                            -85
# PA Min                        140
# PA Max                        170
# short name            Iker Villar
# UUID                   2000211220
# Name: 149, dtype: object
# Row:150 index:Name          Ilias Akhomach Chakkour
# CA                                125
# PA                                -85
# PA Min                            140
# PA Max                            170
# short name             Ilias Akhomach
# UUID                       2000056415
# Name: 150, dtype: object
# Row:151 index:Name          Isaac Achmed Koroma Junior Babadi
# CA                                          120
# PA                                          -85
# PA Min                                      140
# PA Max                                      170
# short name                         Isaac Babadi
# UUID                                 2000087434
# Name: 151, dtype: object
# Row:152 index:Name          Iyenoma Destiny Udogie
# CA                               138
# PA                               -85
# PA Min                           140
# PA Max                           170
# short name            Destiny Udogie
# UUID                        43426047
# Name: 152, dtype: object
# Row:153 index:Name          Jacob Ramsey
# CA                     141
# PA                     170
# PA Min                 170
# PA Max                 170
# short name    Jacob Ramsey
# UUID                  None
# Name: 153, dtype: object
# Row:154 index:Name          Jaime Vázquez Cuervo-Arango
# CA                                     71
# PA                                    -85
# PA Min                                140
# PA Max                                170
# short name                  Jaime Vazquez
# UUID                           2000223081
# Name: 154, dtype: object
# Row:155 index:Name          James John McAtee
# CA                          125
# PA                          -85
# PA Min                      140
# PA Max                      170
# short name         James McAtee
# UUID                   28126249
# Name: 155, dtype: object
# Row:156 index:Name          Jamie Bynoe-Gittens
# CA                            126
# PA                            -85
# PA Min                        140
# PA Max                        170
# short name    Jamie Bynoe-Gittens
# UUID                   2000015300
# Name: 156, dtype: object
# Row:157 index:Name          Jamie Donley
# CA                     107
# PA                     -85
# PA Min                 140
# PA Max                 170
# short name    Jamie Donley
# UUID            2000123638
# Name: 157, dtype: object
# Row:158 index:Name                             Jason van Duiven
# CA                                            115
# ...
# PA                     130
# PA Min                 130
# PA Max                 130
# short name             NaN
# UUID                   NaN
# Name: 7070, dtype: object
# Row:7071 index:Name          Oliver Antman
# CA                      115
# PA                      130
# PA Min                  130
# PA Max                  130
# short name              NaN
# UUID                    NaN
# Name: 7071, dtype: object
# Row:7072 index:Name          Olwethu Makhanya
# CA                          96
# PA                         130
# PA Min                     130
# PA Max                     130
# short name                 NaN
# UUID                       NaN
# Name: 7072, dtype: object
# Row:7073 index:Name          Oskar Krzyżak
# CA                       91
# PA                      130
# PA Min                  130
# PA Max                  130
# short name              NaN
# UUID                    NaN
# Name: 7073, dtype: object
# Row:7074 index:Name          Oupoh Maxime Nagoli
# CA                             82
# PA                            130
# PA Min                        130
# PA Max                        130
# short name                    NaN
# UUID                          NaN
# Name: 7074, dtype: object
# Row:7075 index:Name          Ousmane Marouf Kane
# CA                             98
# PA                            130
# PA Min                        130
# PA Max                        130
# short name                    NaN
# UUID                          NaN
# Name: 7075, dtype: object
# Row:7076 index:Name          Patrick Hessellund Egelund
# CA                                    95
# PA                                   130
# PA Min                               130
# PA Max                               130
# short name                           NaN
# UUID                                 NaN
# Name: 7076, dtype: object
# Row:7077 index:Name          Patrik Myslovic
# CA                        105
# PA                        130
# PA Min                    130
# PA Max                    130
# short name                NaN
# UUID                      NaN
# Name: 7077, dtype: object
# Row:7078 index:Name          Paul Valère Appolinaire Bassène
# CA                                        105
# PA                                        130
# PA Min                                    130
# PA Max                                    130
# short name                                NaN
# UUID                                      NaN
# Name: 7078, dtype: object
# Row:7079 index:Name          Paulo Eduardo Ferreira Godinho
# CA                                       110
# PA                                       130
# PA Min                                   130
# PA Max                                   130
# short name                               NaN
# UUID                                     NaN
# Name: 7079, dtype: object
# Row:7080 index:Name          Pavel Šulc
# CA                   106
# PA                   130
# PA Min               130
# PA Max               130
# short name           NaN
# UUID                 NaN
# Name: 7080, dtype: object
# Row:7081 index:Name          Pietro Boer
# CA                     89
# PA                    130
# PA Min                130
# PA Max                130
# short name            NaN
# UUID                  NaN
# Name: 7081, dtype: object
# Row:7082 index:Name          Pontus Lindgren
# CA                         90
# PA                        130
# PA Min                    130
# PA Max                    130
# short name                NaN
# UUID                      NaN
# Name: 7082, dtype: object
# Row:7083 index:Name          Rafaat Khalil
# CA                       90
# PA                      130
# PA Min                  130
# PA Max                  130
# short name              NaN
# UUID                    NaN
# Name: 7083, dtype: object
# Row:7084 index:Name          Raki Aouani
# CA                     95
# PA                    130
# PA Min                130
# PA Max                130
# short name            NaN
# UUID                  NaN
# Name: 7084, dtype: object
# Row:7085 index:Name          Ramon Ramos Lima
# CA                         115
# PA                         130
# PA Min                     130
# PA Max                     130
# short name                 NaN
# UUID                       NaN
# Name: 7085, dtype: object
# Row:7086 index:Name          Randy Schneider
# CA                        109
# PA                        130
# PA Min                    130
# PA Max                    130
# short name                NaN
# UUID                      NaN
# Name: 7086, dtype: object
# Row:7087 index:Name          Rémy Vita
# CA                  108
# PA                  130
# PA Min              130
# PA Max              130
# short name          NaN
# UUID                NaN
# Name: 7087, dtype: object
# Row:7088 index:Name          Richard Ludha
# CA                      110
# PA                      130
# PA Min                  130
# PA Max                  130
# short name              NaN
# UUID                    NaN
# Name: 7088, dtype: object
# Row:7089 index:Name          Robert Andrés Mejía Navarrete
# CA                                      120
# PA                                      130
# PA Min                                  130
# PA Max                                  130
# short name                              NaN
# UUID                                    NaN
# Name: 7089, dtype: object
# Row:7090 index:Name          Roberto Agustín Ávalos
# CA                               102
# PA                               130
# PA Min                           130
# PA Max                           130
# short name                       NaN
# UUID                             NaN
# Name: 7090, dtype: object
# Row:7091 index:Name          Robin Voisine
# CA                       94
# PA                      130
# PA Min                  130
# PA Max                  130
# short name              NaN
# UUID                    NaN
# Name: 7091, dtype: object
# Row:7092 index:Name          Rodrigo Ezequiel Cabral
# CA                                123
# PA                                130
# PA Min                            130
# PA Max                            130
# short name                        NaN
# UUID                              NaN
# Name: 7092, dtype: object
# Row:7093 index:Name          Rodrigo Leonel Márquez de Meneses
# CA                                          117
# PA                                          130
# PA Min                                      130
# PA Max                                      130
# short name                                  NaN
# UUID                                        NaN
# Name: 7093, dtype: object
# Row:7094 index:Name          Rodrigo Ribeiro Valente
# CA                                 98
# PA                                130
# PA Min                            130
# PA Max                            130
# short name                        NaN
# UUID                              NaN
# Name: 7094, dtype: object
# Row:7095 index:Name          Roman Celentano
# CA                        109
# PA                        130
# PA Min                    130
# PA Max                    130
# short name                NaN
# UUID                      NaN
# Name: 7095, dtype: object
# Row:7096 index:Name          Ronaldo Camará
# CA                        96
# PA                       130
# PA Min                   130
# PA Max                   130
# short name               NaN
# UUID                     NaN
# Name: 7096, dtype: object
# Row:7097 index:Name          Ross Graham
# CA                     97
# PA                    130
# PA Min                130
# PA Max                130
# short name            NaN
# UUID                  NaN
# Name: 7097, dtype: object
# Row:7098 index:Name          Rushwin Wayne Dortley
# CA                              101
# PA                              130
# PA Min                          130
# PA Max                          130
# short name                      NaN
# UUID                            NaN
# Name: 7098, dtype: object
# Row:7099 index:Name          Sacha Delaye
# CA                     105
# PA                     130
# PA Min                 130
# PA Max                 130
# short name             NaN
# UUID                   NaN
# Name: 7099, dtype: object
# Row:7100 index:Name          Samkelo Zwane
# CA                      100
# PA                      130
# PA Min                  130
# PA Max                  130
# short name              NaN
# UUID                    NaN
# Name: 7100, dtype: object
# Row:7101 index:Name          Santiago Velásquez
# CA                           105
# PA                           130
# PA Min                       130
# PA Max                       130
# short name                   NaN
# UUID                         NaN
# Name: 7101, dtype: object
# Row:7102 index:Name          Saud Mohammad Taleb Hassan Bin Taleb Al-Marri
# CA                                                       65
# PA                                                      130
# PA Min                                                  130
# PA Max                                                  130
# short name                                              NaN
# UUID                                                    NaN
# Name: 7102, dtype: object
# Row:7103 index:Name          Shandre Campbell
# CA                          99
# PA                         130
# PA Min                     130
# PA Max                     130
# short name                 NaN
# UUID                       NaN
# Name: 7103, dtype: object
# Row:7104 index:Name          Shkëlqim Vladi
# CA                       111
# PA                       130
# PA Min                   130
# PA Max                   130
# short name               NaN
# UUID                     NaN
# Name: 7104, dtype: object
# Row:7105 index:Name          Shulianskyi Artem Kostiantynovych
# CA                                           92
# PA                                          130
# PA Min                                      130
# PA Max                                      130
# short name                                  NaN
# UUID                                        NaN
# Name: 7105, dtype: object
# Row:7106 index:Name          Simon Janssen
# CA                      107
# PA                      130
# PA Min                  130
# PA Max                  130
# short name              NaN
# UUID                    NaN
# Name: 7106, dtype: object
# Row:7107 index:Name          Sonny Hilton
# CA                      82
# PA                     130
# PA Min                 130
# PA Max                 130
# short name             NaN
# UUID                   NaN
# Name: 7107, dtype: object
# Row:7108 index:Name          Ştefan Baiaram
# CA                       111
# PA                       130
# PA Min                   130
# PA Max                   130
# short name               NaN
# UUID                     NaN
# Name: 7108, dtype: object
# Row:7109 index:Name          Tamás Kiss
# CA                   106
# PA                   130
# PA Min               130
# PA Max               130
# short name           NaN
# UUID                 NaN
# Name: 7109, dtype: object
# Row:7110 index:Name          Taylor Jerome Richards
# CA                               108
# PA                               130
# PA Min                           130
# PA Max                           130
# short name                       NaN
# UUID                             NaN
# Name: 7110, dtype: object
# Row:7111 index:Name          Thiago Eduardo de Andrade
# CA                                  116
# PA                                  130
# PA Min                              130
# PA Max                              130
# short name                          NaN
# UUID                                NaN
# Name: 7111, dtype: object
# Row:7112 index:Name          Thiago Tomás Nuss
# CA                          112
# PA                          130
# PA Min                      130
# PA Max                      130
# short name                  NaN
# UUID                        NaN
# Name: 7112, dtype: object
# Row:7113 index:Name          Tobe Leysen
# CA                     94
# PA                    130
# PA Min                130
# PA Max                130
# short name            NaN
# UUID                  NaN
# Name: 7113, dtype: object
# Row:7114 index:Name          Tobias Koch
# CA                    107
# PA                    130
# PA Min                130
# PA Max                130
# short name            NaN
# UUID                  NaN
# Name: 7114, dtype: object
# Row:7115 index:Name          Tomás Ramiro Muro
# CA                          114
# PA                          130
# PA Min                      130
# PA Max                      130
# short name                  NaN
# UUID                        NaN
# Name: 7115, dtype: object
# Row:7116 index:Name          Tomáš Rigo
# CA                   105
# PA                   130
# PA Min               130
# PA Max               130
# short name           NaN
# UUID                 NaN
# Name: 7116, dtype: object
# Row:7117 index:Name          Viktor Melker Widell
# CA                             115
# PA                             130
# PA Min                         130
# PA Max                         130
# short name                     NaN
# UUID                           NaN
# Name: 7117, dtype: object
# Row:7118 index:Name          Viunnyk Bohdan Serhiiovych
# CA                                   108
# PA                                   130
# PA Min                               130
# PA Max                               130
# short name                           NaN
# UUID                                 NaN
# Name: 7118, dtype: object
# Row:7119 index:Name          Vladislav Lazarev
# CA                          106
# PA                          130
# PA Min                      130
# PA Max                      130
# short name                  NaN
# UUID                        NaN
# Name: 7119, dtype: object
# Row:7120 index:Name          Willem Davnis Louis Didier Geubbels
# CA                                            113
# PA                                            130
# PA Min                                        130
# PA Max                                        130
# short name                                    NaN
# UUID                                          NaN
# Name: 7120, dtype: object
# Row:7121 index:Name          Williams Héctor Alarcón Cepeda
# CA                                       118
# PA                                       130
# PA Min                                   130
# PA Max                                   130
# short name                               NaN
# UUID                                     NaN
# Name: 7121, dtype: object
# Row:7122 index:Name          Xander Severina
# CA                        116
# PA                        130
# PA Min                    130
# PA Max                    130
# short name                NaN
# UUID                      NaN
# Name: 7122, dtype: object
# Row:7123 index:Name          Yanis Begraoui
# CA                       107
# PA                       130
# PA Min                   130
# PA Max                   130
# short name               NaN
# UUID                     NaN
# Name: 7123, dtype: object
# Row:7124 index:Name          Yusuf Özdemir
# CA                      115
# PA                      130
# PA Min                  130
# PA Max                  130
# short name              NaN
# UUID                    NaN
# Name: 7124, dtype: object
# Row:7125 index:Name          Zakaria El Ayeb
# CA                         96
# PA                        130
# PA Min                    130
# PA Max                    130
# short name                NaN
# UUID                      NaN
# Name: 7125, dtype: object
# Row:7126 index:Name          Zakaria Seraj Ahmed Hawsawi
# CA                                    115
# PA                                    130
# PA Min                                130
# PA Max                                130
# short name                            NaN
# UUID                                  NaN
# Name: 7126, dtype: object
# Row:7127 index:Name          Zeno Ibsen Rossi
# CA                          94
# PA                         130
# PA Min                     130
# PA Max                     130
# short name                 NaN
# UUID                       NaN
# Name: 7127, dtype: object
# Row:7128 index:Name          Zied Berrima
# CA                      93
# PA                     130
# PA Min                 130
# PA Max                 130
# short name             NaN
# UUID                   NaN
# Name: 7128, dtype: object

# %%
def process_df(df):
    iterate_count = 0
    time.sleep(5)
    # Go to Training>Indivdual menus
    #orientate()

    # Load your CSV
    #df = pd.read_csv('players_small.csv')
    start_time = time.time()
    # Loop over the dataframe
    # We can also reuse/change our start point
    #last_valid_index = df['short name'].last_valid_index()
    for index, row in df.iloc[6171:].iterrows():
    #for index, row in df.iterrows(): # Originial
    #for index, row in df.items
        try:
            player_name = row['Name']
            #print(f"Player Name: {player_name}")
            short_name, uuid = search_player_and_extract_info(player_name)

            # Update the dataframe
            df.at[index, 'short name'] = short_name
            df.at[index, 'UUID'] = uuid

            # Go back to the main screen or search screen before next iteration
            # This might involve pressing 'esc' or clicking a 'back' button
            pyautogui.press('esc')
        except IndexError:
            #print(f"Unable to locate: {player_name} in your db") 
            unchanged_list.append(player_name)
        
        iterate_count +=1

    # Write the updated dataframe back to CSV
    df.to_csv('players_updated.csv', index=False)
    
    end_time = time.time()
    total_time = end_time - start_time
              
    print(f"Total time: {total_time}")
    print(f"Time per iteration: {total_time/iterate_count}")

# %%
process_df(df)
# Out:
# Total time: 6444.133402585983
# Time per iteration: 6.726652821070964

# %%
df
# Out:
#                                                Name   CA   PA  PA Min  PA Max  \
# 0                       Lamine Yamal Nasraoui Ebana  125  -10     170     200
# 1                          Alejandro Balde Martínez  154  -95     160     190
# 2                             Anssumane Fati Vieira  148  -95     160     190
# 3                   Endrick Felipe Moreira de Sousa  114  -95     160     190
# 4     Estêvão Willian Almeida de Oliveira Gonçalves   75  -95     160     190
# ...                                             ...  ...  ...     ...     ...
# 7124                                  Yusuf Özdemir  115  130     130     130
# 7125                                Zakaria El Ayeb   96  130     130     130
# 7126                    Zakaria Seraj Ahmed Hawsawi  115  130     130     130
# 7127                               Zeno Ibsen Rossi   94  130     130     130
# 7128                                   Zied Berrima   93  130     130     130
#
#                                short name        UUID
# 0                            Lamine Yamal  2000256231
# 1                         Alejandro Balde    67296654
# 2                               Ansu Fati    67276122
# 3                                 Endrick        None
# 4     Q, Game: "Bangoche FM - NK Sesvete"        None
# ...                                   ...         ...
# 7124  Q, Game: "Bangoche FM - NK Sesvete"        None
# 7125  Q, Game: "Bangoche FM - NK Sesvete"        None
# 7126  Q, Game: "Bangoche FM - NK Sesvete"        None
# 7127                     Zeno Ibsen Rossi    28118145
# 7128  Q, Game: "Bangoche FM - NK Sesvete"        None
#
# [7129 rows x 7 columns]

# %%
# %store df
# %store df_cleaned
# Out:
# Stored 'df' (DataFrame)
# Stored 'df_cleaned' (DataFrame)

# %%
df_cleaned = df[df['short name'] != 'Q, Game: "Bangoche FM - NK Sesvete"']

# %%
df_cleaned
# Out:
#                                  Name   CA   PA  PA Min  PA Max  \
# 0         Lamine Yamal Nasraoui Ebana  125  -10     170     200
# 1            Alejandro Balde Martínez  154  -95     160     190
# 2               Anssumane Fati Vieira  148  -95     160     190
# 3     Endrick Felipe Moreira de Sousa  114  -95     160     190
# 5                   Evan Joe Ferguson  138  -95     160     190
# ...                               ...  ...  ...     ...     ...
# 7114                      Tobias Koch  107  130     130     130
# 7116                       Tomáš Rigo  105  130     130     130
# 7119                Vladislav Lazarev  106  130     130     130
# 7122                  Xander Severina  116  130     130     130
# 7127                 Zeno Ibsen Rossi   94  130     130     130
#
#                short name        UUID
# 0            Lamine Yamal  2000256231
# 1         Alejandro Balde    67296654
# 2               Ansu Fati    67276122
# 3                 Endrick        None
# 5           Evan Ferguson        None
# ...                   ...         ...
# 7114         Tobias Boche  2000071500
# 7116     Tommaso Arrigoni    43082780
# 7119  Vladislav Lazarevic  2002100251
# 7122      Xander Severina        None
# 7127     Zeno Ibsen Rossi    28118145
#
# [3299 rows x 7 columns]

# %%
#!pip install fuzzywuzzy
#!pip install fuzzywuzzy[speedup]
#from fuzzywuzzy import fuzz

#fuzz.ratio(df_cleaned['Name'], df_cleaned['short name'])
for index, row in df_cleaned.iterrows():
    #print(f"Long Name: {row['Name']}")
    try:
        if fuzz.ratio(row['Name'], row['short name']) < 30 and row['UUID'] is not None:
            print(f"Long Name: {row['Name']}  Short Name: {row['short name']}")
        #print(f"Fuzz ratio {fuzz.ratio(row['Name'], row['short name'])}")
    except TypeError:
        pass
# Out:
# Long Name: Pablo Martín Páez Gavira  Short Name: Gavi
# Long Name: Kees Smit  Short Name: Mitch Clark
# Long Name: Sávio Moreira de Oliveira  Short Name: Savio
# Long Name: Tygo Land  Short Name: Lee Sang-Hyeok
# Long Name: Luka Sučić  Short Name: Kai Havertz
# Long Name: Adrián Arnuncio Baquerín  Short Name: Arnu
# Long Name: Agustín Giay  Short Name: Jean Pierre Barrientos
# Long Name: José David Menargues Manzanarez  Short Name: Joseda
# Long Name: Luca Neu  Short Name: Club Atlético Boca Juniors
# Long Name: Nicolas González Iglesias  Short Name: Nico
# Long Name: Roger Fernandes  Short Name: Kenneth
# Long Name: Felipe Rodrigues da Silva  Short Name: Morato
# Long Name: Álvaro Pérez Campo  Short Name: Trilli
# Long Name: Ambrosini Antonio Cabaça Salvador  Short Name: Zini
# Long Name: Ariel Mosór  Short Name: Q, Cata
# Long Name: Axel Perez  Short Name: Biel
# Long Name: Dies Janse  Short Name: Juanma Lillo
# Long Name: Emre Kaya  Short Name: CS Minaur Baia Mare
# Long Name: Enzo Faty  Short Name: Q, Fath Union Sport Rabat
# Long Name: Eyüp Aydın  Short Name: Mathew Ryan
# Long Name: Francisco Javier González Pérez  Short Name: Fran
# Long Name: François Mendy  Short Name: Kenny Jackett
# Long Name: Guela Doué  Short Name: A
# Long Name: Han-Beom Lee  Short Name: Teemu Pukki
# Long Name: Iker Gil López  Short Name: Eder
# Long Name: Janis Lüthi  Short Name: Q, Andrei Stoia
# Long Name: Jorge García  Short Name: Marquinhos
# Long Name: José María Andrés Baixauli  Short Name: Chema
# Long Name: Lukáš Mašek  Short Name: Suso
# Long Name: Mamadou Sow  Short Name: Momo Mbaye
# Long Name: Pablo Pagis  Short Name: Davis Bautista
# Long Name: Roey Magor  Short Name: Namory Cissé
# Long Name: Savo Sušić  Short Name: Joselu
# Long Name: Tine Čuk  Short Name: Kuki Zalazar
# Long Name: Yeremay Hernández Cubas  Short Name: Peke
# Long Name: Yoël van den Ban  Short Name: Oscar
# Long Name: Yoni Gomis  Short Name: Toti
# Long Name: Youssef Enriquez Lekhedim  Short Name: Yusi
# Long Name: Logan Costa  Short Name: Gustaf Lagerbielke
# Long Name: Peter Federico González Carmona  Short Name: Peter
# Long Name: Aimar González de Heredia Murgialday  Short Name: Aimar
# Long Name: Ali Hassan  Short Name: @, Mahdi Ali
# Long Name: Aly Sy  Short Name: Kessy Coulibaly
# Long Name: Arda Özçimen  Short Name: Jaume Costa
# Long Name: Efe Can Mete  Short Name: Pepe Reina
# Long Name: Emilio González Nosti  Short Name: Emi
# Long Name: Enes Öğrüce  Short Name: Marcello Benesperi
# Long Name: Enes Yetkin  Short Name: Gethin Jones
# Long Name: Enrique Maza Díaz  Short Name: Carlos Faya
# Long Name: Erik Dueñas  Short Name: Lucas Ocampos
# Long Name: Francisco Davi da Penha Sousa  Short Name: Davi
# Long Name: Franco Caro  Short Name: Wout Weghorst
# Long Name: Guilherme Borges Guedes  Short Name: Gui
# Long Name: Hadji Dramé  Short Name: Ramon Arias Madrid
# Long Name: Hamza Gasal  Short Name: Basile Yamkam
# Long Name: Hugues Neya  Short Name: Renan Guedes
# Long Name: Iván José Martín  Short Name: George Long
# Long Name: Jalen Neal  Short Name: Greek Super League 1
# Long Name: Jesús Gómez  Short Name: Suso
# Long Name: Joaquín Jara  Short Name: Quini
# Long Name: Jorge Montes García  Short Name: Pablo Cortés
# Long Name: José Antonio Ángel García  Short Name: Kikin
# Long Name: Josué Díaz González  Short Name: Paco Corredoira
# Long Name: Kenzo Kies  Short Name: Martin Bengoa
# Long Name: Kerem Matışlı  Short Name: Q, Fatih Terim
# Long Name: Leo Walta  Short Name: Sebastian Kehl
# Long Name: Michal Ševčík  Short Name: Ched Evans
# Long Name: Milad Kor  Short Name: Alex Oxlade-Chamberlain
# Long Name: Noah Cobb  Short Name: Joao Palhinha
# Long Name: Olaf Gorter  Short Name: Blas
# Long Name: Pablo García Fernández  Short Name: Roberto Carlos
# Long Name: Pedro Henrique Franklim da Silva  Short Name: Pedrao
# Long Name: Raf Vullers  Short Name: F
# Long Name: Rocco Ríos Novo  Short Name: Q, Heiwa Sozo-no-mori Park Soccer Ground
# Long Name: Ryad Talbi  Short Name: Imad
# Long Name: Ryan Rodin  Short Name: Eric Maxim Choupo-Moting
# Long Name: Samba Koné  Short Name: Joél Piroe
# Long Name: Šimon Faško  Short Name: Monchi
# Long Name: Šimun Mikolčić  Short Name: Ivan Todorov
# Long Name: Uroš Ćuk  Short Name: Luka Kurolt
# Long Name: Wassim Keddari Boullif  Short Name: Simo
# Long Name: Tomáš Čvančara  Short Name: Vanarama National League
# Long Name: Alberto Marí Sánchez  Short Name: Dani Pendin
# Long Name: Franco Martín Díaz  Short Name: Raul Martin Gonzalez Francés
# Long Name: Luka Vešner Tičić  Short Name: SAINS
# Long Name: Amar Begić  Short Name: Q, José Mourinho
# Long Name: Can Keleş  Short Name: Q, José Mourinho
# Long Name: Efraín Álvarez  Short Name: Christian Moran
# Long Name: Rafail Mamas  Short Name: Pipo
# Long Name: Mohamed Koné  Short Name: Q, Aron Winter
# Long Name: Breno Henrique Neres Teixeira  Short Name: Breno
# Long Name: Dan Sîrbu  Short Name: Q, Xavi
# Long Name: Matyáš Kozák  Short Name: New York City FC
# Long Name: Neo Rapoo  Short Name: Hapoel Tel-Aviv
# Long Name: Rémy Vita  Short Name: Umut Bozok

# %%
def my_fuzz(x,y):
    try:
        if fuzz.ratio(x, y) < 30:
            print(f"Long Name: {row['Name']}  Short Name: {row['short name']}")
        #print(f"Fuzz ratio {fuzz.ratio(row['Name'], row['short name'])}")
    except TypeError:
        pass
#result = [my_fuzz(x,y) for x,y  in zip(df_cleaned['Name'], df_cleaned['short name'])]
#print(result)
def my_row_fuzz(long_name, short_name, uuid):
    try:
        if fuzz.ratio(long_name, short_name) < 30 and uuid is not None:
            return (f"Long Name: {long_name}  Short Name: {short_name}")
        #print(f"Fuzz ratio {fuzz.ratio(row['Name'], row['short name'])}")
    except TypeError:
        pass

for row in df_cleaned.itertuples():
    result = my_row_fuzz(row[1], row[6], row[7])
    if result:
        print(f"Name {result}")
# Out:
# Name Long Name: Pablo Martín Páez Gavira  Short Name: Gavi
# Name Long Name: Kees Smit  Short Name: Mitch Clark
# Name Long Name: Sávio Moreira de Oliveira  Short Name: Savio
# Name Long Name: Tygo Land  Short Name: Lee Sang-Hyeok
# Name Long Name: Luka Sučić  Short Name: Kai Havertz
# Name Long Name: Adrián Arnuncio Baquerín  Short Name: Arnu
# Name Long Name: Agustín Giay  Short Name: Jean Pierre Barrientos
# Name Long Name: José David Menargues Manzanarez  Short Name: Joseda
# Name Long Name: Luca Neu  Short Name: Club Atlético Boca Juniors
# Name Long Name: Nicolas González Iglesias  Short Name: Nico
# Name Long Name: Roger Fernandes  Short Name: Kenneth
# Name Long Name: Felipe Rodrigues da Silva  Short Name: Morato
# Name Long Name: Álvaro Pérez Campo  Short Name: Trilli
# Name Long Name: Ambrosini Antonio Cabaça Salvador  Short Name: Zini
# Name Long Name: Ariel Mosór  Short Name: Q, Cata
# Name Long Name: Axel Perez  Short Name: Biel
# Name Long Name: Dies Janse  Short Name: Juanma Lillo
# Name Long Name: Emre Kaya  Short Name: CS Minaur Baia Mare
# Name Long Name: Enzo Faty  Short Name: Q, Fath Union Sport Rabat
# Name Long Name: Eyüp Aydın  Short Name: Mathew Ryan
# Name Long Name: Francisco Javier González Pérez  Short Name: Fran
# Name Long Name: François Mendy  Short Name: Kenny Jackett
# Name Long Name: Guela Doué  Short Name: A
# Name Long Name: Han-Beom Lee  Short Name: Teemu Pukki
# Name Long Name: Iker Gil López  Short Name: Eder
# Name Long Name: Janis Lüthi  Short Name: Q, Andrei Stoia
# Name Long Name: Jorge García  Short Name: Marquinhos
# Name Long Name: José María Andrés Baixauli  Short Name: Chema
# Name Long Name: Lukáš Mašek  Short Name: Suso
# Name Long Name: Mamadou Sow  Short Name: Momo Mbaye
# Name Long Name: Pablo Pagis  Short Name: Davis Bautista
# Name Long Name: Roey Magor  Short Name: Namory Cissé
# Name Long Name: Savo Sušić  Short Name: Joselu
# Name Long Name: Tine Čuk  Short Name: Kuki Zalazar
# Name Long Name: Yeremay Hernández Cubas  Short Name: Peke
# Name Long Name: Yoël van den Ban  Short Name: Oscar
# Name Long Name: Yoni Gomis  Short Name: Toti
# Name Long Name: Youssef Enriquez Lekhedim  Short Name: Yusi
# Name Long Name: Logan Costa  Short Name: Gustaf Lagerbielke
# Name Long Name: Peter Federico González Carmona  Short Name: Peter
# Name Long Name: Aimar González de Heredia Murgialday  Short Name: Aimar
# Name Long Name: Ali Hassan  Short Name: @, Mahdi Ali
# Name Long Name: Aly Sy  Short Name: Kessy Coulibaly
# Name Long Name: Arda Özçimen  Short Name: Jaume Costa
# Name Long Name: Efe Can Mete  Short Name: Pepe Reina
# Name Long Name: Emilio González Nosti  Short Name: Emi
# Name Long Name: Enes Öğrüce  Short Name: Marcello Benesperi
# Name Long Name: Enes Yetkin  Short Name: Gethin Jones
# Name Long Name: Enrique Maza Díaz  Short Name: Carlos Faya
# Name Long Name: Erik Dueñas  Short Name: Lucas Ocampos
# Name Long Name: Francisco Davi da Penha Sousa  Short Name: Davi
# Name Long Name: Franco Caro  Short Name: Wout Weghorst
# Name Long Name: Guilherme Borges Guedes  Short Name: Gui
# Name Long Name: Hadji Dramé  Short Name: Ramon Arias Madrid
# Name Long Name: Hamza Gasal  Short Name: Basile Yamkam
# Name Long Name: Hugues Neya  Short Name: Renan Guedes
# Name Long Name: Iván José Martín  Short Name: George Long
# Name Long Name: Jalen Neal  Short Name: Greek Super League 1
# Name Long Name: Jesús Gómez  Short Name: Suso
# Name Long Name: Joaquín Jara  Short Name: Quini
# Name Long Name: Jorge Montes García  Short Name: Pablo Cortés
# Name Long Name: José Antonio Ángel García  Short Name: Kikin
# Name Long Name: Josué Díaz González  Short Name: Paco Corredoira
# Name Long Name: Kenzo Kies  Short Name: Martin Bengoa
# Name Long Name: Kerem Matışlı  Short Name: Q, Fatih Terim
# Name Long Name: Leo Walta  Short Name: Sebastian Kehl
# Name Long Name: Michal Ševčík  Short Name: Ched Evans
# Name Long Name: Milad Kor  Short Name: Alex Oxlade-Chamberlain
# Name Long Name: Noah Cobb  Short Name: Joao Palhinha
# Name Long Name: Olaf Gorter  Short Name: Blas
# Name Long Name: Pablo García Fernández  Short Name: Roberto Carlos
# Name Long Name: Pedro Henrique Franklim da Silva  Short Name: Pedrao
# Name Long Name: Raf Vullers  Short Name: F
# Name Long Name: Rocco Ríos Novo  Short Name: Q, Heiwa Sozo-no-mori Park Soccer Ground
# Name Long Name: Ryad Talbi  Short Name: Imad
# Name Long Name: Ryan Rodin  Short Name: Eric Maxim Choupo-Moting
# Name Long Name: Samba Koné  Short Name: Joél Piroe
# Name Long Name: Šimon Faško  Short Name: Monchi
# Name Long Name: Šimun Mikolčić  Short Name: Ivan Todorov
# Name Long Name: Uroš Ćuk  Short Name: Luka Kurolt
# Name Long Name: Wassim Keddari Boullif  Short Name: Simo
# Name Long Name: Tomáš Čvančara  Short Name: Vanarama National League
# Name Long Name: Alberto Marí Sánchez  Short Name: Dani Pendin
# Name Long Name: Franco Martín Díaz  Short Name: Raul Martin Gonzalez Francés
# Name Long Name: Luka Vešner Tičić  Short Name: SAINS
# Name Long Name: Amar Begić  Short Name: Q, José Mourinho
# Name Long Name: Can Keleş  Short Name: Q, José Mourinho
# Name Long Name: Efraín Álvarez  Short Name: Christian Moran
# Name Long Name: Rafail Mamas  Short Name: Pipo
# Name Long Name: Mohamed Koné  Short Name: Q, Aron Winter
# Name Long Name: Breno Henrique Neres Teixeira  Short Name: Breno
# Name Long Name: Dan Sîrbu  Short Name: Q, Xavi
# Name Long Name: Matyáš Kozák  Short Name: New York City FC
# Name Long Name: Neo Rapoo  Short Name: Hapoel Tel-Aviv
# Name Long Name: Rémy Vita  Short Name: Umut Bozok

# %%
df.to_csv('players_updated.csv', index=False)

# %%
num_not_nans = df['short name'].count()
                  
last_valid_index = df['short name'].last_valid_index()
#for i in range(last_valid_index +1, len(df)):
    # do something with row
#    pass
print(last_valid_index)
# Out:
# 1229

# %%
num_not_nans = df['short name'].count()
                  
last_valid_index = df['short name'].last_valid_index()
#for i in range(last_valid_index +1, len(df)):
    # do something with row
#    pass
                  
# We can also reuse/change our start point
last_valid_index = df['short name'].last_valid_index()
for index, row in df.loc[last_valid_index+1].iterrows():
    # do something with row
    pass

# %%
# Test with a free agent De Gea
david_de_gea = "David De Gea"
time.sleep(5)
search_player_and_extract_info(david_de_gea)

# %%
de_gea_text = 'David De Gea\nGoalkeeper (1ID:67030171)\n'
de_gea_text_data = de_gea_text.split("\n")
print(de_gea_text_data)
for line in de_gea_text_data:
    print(line)
len(de_gea_text_data)

# %%
lamine_text = 'Q 27. Lamine Yamal\nAttacking Midfielder (Right, Left), Striker (Center) - Barcelona (ID:2000256231)\n'
lamine_text_data = lamine_text.split("\n")
print(lamine_text_data)
for line in lamine_text_data:
    print(line)
#len(lamine_text_data)

# %%
text = '9. Vitor Roque'
#text = '@ 31. Ansu Fati'
result = re.sub(r'^.*?\d+\.\s*', "",text)
print(result)

# %%
beautifulsoup4==4.11.1
certifi==2022.12.7
charset-normalizer==2.1.1
idna==3.4
lxml==4.9.2
Pillow==9.3.0
requests==2.28.1
soupsieve==2.3.2.post1
urllib3==1.26.13

# %%
import os
os.getcwd()
os.chdir("C:\\Users\\lover\\OneDrive\\Documents\\GitHub\\soccer-card-project\\")
os.getcwd()

#!python -m "C:\\Users\\lover\\OneDrive\\Documents\\GitHub\\soccer-card-project\\main"
# Out:
# 'C:\\Users\\lover\\OneDrive\\Documents\\GitHub\\soccer-card-project'

# %%
import requests
import random
import pathlib
import urllib.request
import os.path
from lxml import etree
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
from bs4 import BeautifulSoup

headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}

playerNames = []
playerNos = []
playerImageLinks = []
teamNames = []
teamIds = []

def get_team_names_and_ids():

    leagueLinkAddress = 'https://www.transfermarkt.com.tr/super-lig/startseite/wettbewerb/TR1'

    leagueTreeResponse = requests.get(leagueLinkAddress, headers=headers)
    soupLeague = BeautifulSoup(leagueTreeResponse.content, 'html.parser')

    teamNamesTree = (etree.HTML(str(soupLeague)).xpath('/html/body/div[2]/main/div[2]/div[1]/div[2]/div[2]/div/table/tbody/tr'))

    for i in range(len(teamNamesTree)):

        if teamNamesTree[i].xpath('td[2]/a')[0].text != '':
            teamNames.append(teamNamesTree[i].xpath('td[2]/a/@href')[0].split('/')[1])
            teamIds.append(teamNamesTree[i].xpath('td[2]/a/@href')[0].split('/')[4])

def get_team_colors(teamColors):

    for i in range(len(teamNames)):

        temaColorUrl = 'https://www.transfermarkt.com.tr/' + teamNames[i] + '/datenfakten/verein/' + teamIds[i]

        tree = requests.get(temaColorUrl, headers=headers)
        soup = BeautifulSoup(tree.content, 'html.parser')

        arr = soup.findAll('p', class_='vereinsfarbe')

        if len(arr) == 0:
            randomColor1 = ("#" + ''.join([random.choice('ABCDEF0123456789') for i in range(6)])).lstrip('#')
            randomColor2 = ("#" + ''.join([random.choice('ABCDEF0123456789') for i in range(6)])).lstrip('#')

            teamColors[i][0] = tuple(int(randomColor1[i:i + 2], 16) for i in (0, 2, 4))
            teamColors[i][1] = tuple(int(randomColor2[i:i + 2], 16) for i in (0, 2, 4))

        else:
            h1 = arr[0].findAll('span')[0]["style"].split(':')[1].rstrip(";").lstrip('#')
            h2 = arr[0].findAll('span')[1]["style"].split(':')[1].rstrip(";").lstrip('#')

            teamColors[i][0] = tuple(int(h1[i:i + 2], 16) for i in (0, 2, 4))
            teamColors[i][1] = tuple(int(h2[i:i + 2], 16) for i in (0, 2, 4))

def get_player_datas(playerInfos):

    for i in range(len(teamNames)):

        playerNames.clear()
        playerImageLinks.clear()
        playerNos.clear()

        page = 'https://www.transfermarkt.com.tr/' + teamNames[i] + '/startseite/verein/' + teamIds[i]

        tree = requests.get(page, headers=headers)
        soup = BeautifulSoup(tree.content, 'html.parser')

        playerInfos[i][0] = teamNames[i]

        players = soup.findAll('img', class_='bilderrahmen-fixed')

        for j in range(len(players)):
            if players[j]['title'] != '':
                playerNames.append(players[j]['title'].replace(" ", "-").lower())

                playerLink = soup.find('a', attrs={'title':players[j]['title']})

                pagePlayerInfo = 'https://www.transfermarkt.com.tr' + playerLink.findNext('a')['href']
                treePlayerInfo = requests.get(pagePlayerInfo, headers=headers)
                soupPlayerInfo = BeautifulSoup(treePlayerInfo.content, 'html.parser')

                playerName = players[j]['title']

                age = soupPlayerInfo.find('span',attrs={'class':'data-header__content', 'itemprop':'birthDate'})
                randomAge = random.randint(15, 39)
                strAge = age.text.replace(" ", "").split('(')[1][:2] if age is not None else str(randomAge)
                playerAge = strAge

                number = soupPlayerInfo.find('span',attrs={'class':'data-header__shirt-number'})
                randomNumber = random.randint(0, 99)

                while randomNumber in playerNos:
                    randomNumber = random.randint(0, 99)

                playerNos.append(randomNumber)
                strNumber = number.text.replace(" ", "")[2:] if number is not None else str(randomNumber)
                playerNumber = strNumber

                value = soupPlayerInfo.find('a',attrs={'class':'data-header__market-value-wrapper'})

                thousandOrMillion = random.randint(0, 1)

                if thousandOrMillion == 1:
                    randomValue = random.randint(50, 999)
                    strValue = value.text.split('€')[0] if value is not None else str(randomValue) + " Bin "
                else:
                    randomValue = random.randint(1, 15)
                    strValue = value.text.split('€')[0] if value is not None else str(randomValue) + ".00 mil. "

                playerValue = strValue + "€"

                height = soupPlayerInfo.find('span',attrs={'class':'data-header__content', 'itemprop':'height'})
                playerHeight = height.text if height is not None else str(round(random.uniform(1.6, 2.0), 2)) + " m"
                strHeight = playerHeight.replace(" ", "").replace("m", "").replace(",", "").replace(".", "")

                playerWeight = str(round(calculate_age_constant(int(playerAge)) * (int(strHeight) - 105))) + " kg"

                playerInfos[i][1].append(playerName)
                playerInfos[i][2].append(playerAge)
                playerInfos[i][3].append(playerNumber)
                playerInfos[i][4].append(playerValue)
                playerInfos[i][5].append(playerHeight)
                playerInfos[i][6].append(playerWeight)

        for playerImageLink in soup.findAll('img', class_='bilderrahmen-fixed'):

            playerImageLinks.append(playerImageLink['data-src'].replace("small", "header"))

        for j in range(len(playerNames)):

            absolute_path = os.path.dirname(__file__)
            relative_path = "output-photos\\player-photos\\" + teamNames[i] + "\\"
            full_path = os.path.join(absolute_path, relative_path)

            if not os.path.isdir(full_path):
                pathlib.Path(full_path).mkdir(parents=True, exist_ok=True)

            urllib.request.urlretrieve(playerImageLinks[j], full_path + playerNames[j] + '.png')

def calculate_age_constant(ageValue):
    if ageValue < 15:
        return 0.9
    elif ageValue >= 15 and ageValue < 20:
        return 0.95
    elif ageValue >= 20 and ageValue < 25:
        return 1.00
    elif ageValue >= 25 and ageValue < 30:
        return 1.00
    elif ageValue >= 30 and ageValue < 35:
        return 1.00
    elif ageValue >= 35 and ageValue < 40:
        return 1.05
    else:
        return 1.1

def create_team_card_templates(teamColors):

    for i in range(len(teamNames)):

        absolute_path = os.path.dirname(__file__)

        flag_inside1 = Image.open(absolute_path + "\\base-photos\\flag-inside-1.png")
        flag_inside2 = Image.open(absolute_path + "\\base-photos\\flag-inside-2.png")
        inline_border = Image.open(absolute_path + "\\base-photos\\inline-border.png")

        new_image1 = []
        new_image2 = []
        new_image3 = []

        flag_inside1 = flag_inside1.convert("RGBA")
        flag_inside2 = flag_inside2.convert("RGBA")
        inline_border = inline_border.convert("RGBA")

        d1 = flag_inside1.getdata()
        d2 = flag_inside2.getdata()
        d3 = inline_border.getdata()

        color1 = teamColors[i][0]
        color2 = teamColors[i][1]

        for item in d1:

            if item[0] in list(range(200, 256)):
                new_image1.append(color1)
            else:
                new_image1.append(item)

        for item in d2:

            if item[0] in list(range(200, 256)):
                new_image2.append(color2)
            else:
                new_image2.append(item)

        for item in d3:

            if item[0] in list(range(200, 256)):
                new_image3.append(color1)
            else:
                new_image3.append(item)

        flag_inside1.putdata(new_image1)
        flag_inside2.putdata(new_image2)
        inline_border.putdata(new_image3)

        relative_path = "output-photos\\team-templates\\" + teamNames[i] + "\\"
        full_path = os.path.join(absolute_path, relative_path)

        if not os.path.isdir(full_path):
            pathlib.Path(full_path).mkdir(parents=True, exist_ok=True)

        flag_inside1.save(full_path + "flag-inside1.png")

        flag_inside2.save(full_path + "flag-inside2.png")

        inline_border.save(full_path + "inline-border.png")

def generate_team_cards(playerInfos):

    for i in range(len(playerInfos)):

        for j in range(len(playerInfos[i][1])):

            absolute_path = os.path.dirname(__file__)

            background = Image.open(absolute_path + "\\base-photos\\background.png")
            base_info = Image.open(absolute_path + "\\base-photos\\base-info.png")
            flag_border = Image.open(absolute_path + "\\base-photos\\flag-border.png")

            flag_inside1 = Image.open(absolute_path + "\\output-photos\\team-templates\\" + playerInfos[i][0] + "\\" + "flag-inside1.png")
            flag_inside2 = Image.open(absolute_path + "\\output-photos\\team-templates\\" + playerInfos[i][0] + "\\" + "flag-inside2.png")
            inline_border = Image.open(absolute_path + "\\output-photos\\team-templates\\" + playerInfos[i][0] + "\\" + "inline-border.png")

            photo = Image.open(absolute_path + "\\output-photos\\player-photos\\" + playerInfos[i][0] + "\\" + playerInfos[i][1][j].replace(" ", "-").lower() + ".png")

            photo = photo.resize((550, 700))

            im = Image.new(mode="RGBA", size=(background.width, background.height))

            im.paste(photo, (150, 110))

            relative_path = "output-photos\\resized-player-photos\\" + playerInfos[i][0] + "\\"

            full_path = os.path.join(absolute_path, relative_path)

            if not os.path.isdir(full_path):
                pathlib.Path(full_path).mkdir(parents=True, exist_ok=True)

            im.save(full_path + playerInfos[i][1][j].replace(" ", "-").lower() + ".png")

            photo = Image.open(full_path + playerInfos[i][1][j].replace(" ", "-").lower() + ".png")

            img1 = Image.alpha_composite(background, photo)
            img2 = Image.alpha_composite(img1, base_info)
            img3 = Image.alpha_composite(img2, inline_border)
            img4 = Image.alpha_composite(img3, flag_inside1)
            img5 = Image.alpha_composite(img4, flag_inside2)
            img6 = Image.alpha_composite(img5, flag_border)

            i1 = ImageDraw.Draw(img6)

            nameFont = ImageFont.truetype(absolute_path + '\\fonts\\arial-narrow.ttf', 60)
            infoFont = ImageFont.truetype(absolute_path + '\\fonts\\UniversalisADFStd-CondItalic.otf', 53)
            numberFont = ImageFont.truetype(absolute_path + '\\fonts\\arial.ttf', 60)

            name = playerInfos[i][1][j]

            age = playerInfos[i][2][j]
            weight = playerInfos[i][6][j]
            height = playerInfos[i][5][j]
            value = playerInfos[i][4][j]
            number = playerInfos[i][3][j]

            i1.text((img6.width/2, 902), name, font=nameFont, fill=(0, 0, 0), anchor="mm")

            i1.text((img6.width/4, 1028), age, font=infoFont, fill=(0, 0, 0), anchor="mm")
            i1.text((img6.width*(3/4), 1028), weight, font=infoFont, fill=(0, 0, 0), anchor="mm")
            i1.text((img6.width/4 + 40, 1120), height, font=infoFont, fill=(0, 0, 0), anchor="mm")
            i1.text((img6.width*(3/4) + 50, 1120), value, font=infoFont, fill=(0, 0, 0), anchor="mm")
            i1.text((img6.width*(3/4) + 92, 125), number, font=numberFont, fill=(0, 0, 0), anchor="mm")

            relative_path = "output-photos\\final-results\\" + playerInfos[i][0] + "\\"

            full_path = os.path.join(absolute_path, relative_path)

            if not os.path.isdir(full_path):
                pathlib.Path(full_path).mkdir(parents=True, exist_ok=True)

            img6.save(full_path + playerInfos[i][1][j].replace(" ", "-").lower() + ".png")

def main():
    get_team_names_and_ids()

    teamColors = [[0 for i in range(2)] for j in range(len(teamNames))]
    playerInfos = [[str(), list(), list(), list(), list(), list(), list()] for j in range(len(teamNames))]

    get_team_colors(teamColors)
    get_player_datas(playerInfos)
    create_team_card_templates(teamColors)
    generate_team_cards(playerInfos)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[175], line 308
#     305     generate_team_cards(playerInfos)
#     307 if __name__ == "__main__":
# --> 308     main()
#
# Cell In[175], line 303, in main()
#     300 playerInfos = [[str(), list(), list(), list(), list(), list(), list()] for j in range(len(teamNames))]
#     302 get_team_colors(teamColors)
# --> 303 get_player_datas(playerInfos)
#     304 create_team_card_templates(teamColors)
#     305 generate_team_cards(playerInfos)
#
# Cell In[175], line 83, in get_player_datas(playerInfos)
#      79 playerNames.append(players[j]['title'].replace(" ", "-").lower())
#      81 playerLink = soup.find('a', attrs={'title':players[j]['title']})
# ---> 83 pagePlayerInfo = 'https://www.transfermarkt.com.tr' + playerLink.findNext('a')['href']
#      84 treePlayerInfo = requests.get(pagePlayerInfo, headers=headers)
#      85 soupPlayerInfo = BeautifulSoup(treePlayerInfo.content, 'html.parser')
#
# AttributeError: 'NoneType' object has no attribute 'findNext'

# %% [markdown]
# # How to iterate over Pandas dataframes....( you don't)
# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas

# %%
# NK Sesvete Transfermarkt URL
# https://www.transfermarkt.com/nk-sesvete/startseite/verein/25029
#!pip install requests
# !pip install html5

# %%
# Read in simple view data from FM

simple_sesvete_data = pd.read_html('sesvete_fm_data.html')

# %%
import requests
from bs4 import BeautifulSoup
import pprint
import shutil
import requests

import os

NULL_IMG = 'https://img.a.transfermarkt.technology/portrait/medium/default.jpg?lm=1'
URL = "https://www.transfermarkt.com/nk-sesvete/kader/verein/25029/saison_id/2023/plus/1"
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36 Edg/118.0.2088.76'}


#page = requests.get(URL)

headers = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36 Edg/118.0.2088.76'


def my_tfmrkt_fuzz(player_name, fm_player_name, uuid):
    #print(f"Processing {fm_player_name}")
    try:
        if fuzz.ratio(player_name, fm_player_name) > 75:
            print(f"TFMRKT Name: {player_name}  FM Name: {fm_player_name} UUID {uuid}")
            return uuid
        #print(f"Fuzz ratio {fuzz.ratio(row['Name'], row['short name'])}")
    except TypeError:
        pass
    return None


def download_jpg(uuid, url):
    out_file_name = './images/' + str(uuid) + '.jpg'
    response = requests.get(url, stream=True)
    with open(out_file_name, 'wb') as out_file:
        shutil.copyfileobj(response.raw, out_file)
    del response
    
    
    
    
#sesvete_html_df = pd.read_html('sesvete_web.html')
#sesvete_html_df[1]
os.chdir("C:\\Users\\lover\\OneDrive\\Documents\\GitHub\\football_manager_code")
print(f"DIR {os.getcwd()}")

# This functions with local file
# with open('sesvete_web.html', 'r') as input_html:
#    page = input_html.read()


headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36 Edg/118.0.2088.76'}
#url = 'https://www.transfermarkt.com/nk-sesvete/kader/verein/25029/saison_id/2023/plus/1'
response = requests.get(URL, headers=headers)

soup = BeautifulSoup(response.content, "html.parser")


#with open('fm_data.html', 'r') as input_fm_html:
#    fm_html = input_fm_html.read()
    
fm_data_df = pd.read_html('fm_data.html')

#with open('sesvete_fm_data.html', 'r') as input_fm:
#    fm_data = input_fm.read()
#soup = BeautifulSoup(page, "html.parser")

#results = soup.find(id="yw1")
#print(results.prettify())
#job_elements = results.find_all("div", class_="card-content")
#for job_element in job_elements:
#    print(job_element, end="\n"*2)
    
player_table = soup.find("table", class_="items")
# print(player_table.prettify())

images_found = player_table.find_all("img", class_="bilderrahmen-fixed lazy lazy")
#len(images_found)
#pprint.pprint(images_found)

for found_image in images_found: 
    #dir(found_image)
    image_source = found_image["data-src"]
    if image_source != NULL_IMG:
        player_name = found_image["title"]
        #print(f"Name: {player_name.strip()}\nIMG: {image_source.strip()}\n")
        # Attempt a fuzzy match based on name in Transfermkrt
        for row in fm_data_df[0].itertuples():
            fm_player_name = row[5].split("-")[0].strip()
            result = my_tfmrkt_fuzz(player_name, fm_player_name, row[2])
            if result:
                print(f"Download {image_source} and save as UUID {result}.jpg")
                print("\n")
                # Download image and use UUID to name its download filename
                download_jpg(result, image_source)
        
#img_elements = bilderrahmen-fixed lazy entered loaded

# %%
type(fm_data_df)
# Out:
# list

# %%
#for row in fm_data_df:
#    print(f"Row is {row}")
type(fm_data_df[0])

# ARE YOU SERIOUS The read_html creates the dataframe inside of a surrounding LIST?!!!
#fm_data_df[0]['UID']

for data_crap in fm_data_df[0].itertuples():
    #print(data_crap[2])
    print(data_crap)
    print()
# Out:
# Pandas(Index=0, _1='DCR', UID=2000128602, Inf='Vac', _4=nan, Player='Dominik Braun - Pick Player', Nat='CRO', Height='6\'3"', Weight='176 lbs', Age=19)
#
# Pandas(Index=1, _1='MCL', UID=24065096, Inf='Vac', _4=nan, Player='Tomislav Duvnjak - Pick Player', Nat='CRO', Height='5\'9"', Weight='160 lbs', Age=20)
#
# Pandas(Index=2, _1='STC', UID=24053019, Inf='Vac', _4=nan, Player='Ivor LjubanoviÄ\x87 - Pick Player', Nat='CRO', Height='5\'10"', Weight='165 lbs', Age=24)
#
# Pandas(Index=3, _1='AMR', UID=24050863, Inf='Vac', _4=nan, Player='Mateo TopiÄ\x87 - Pick Player', Nat='CRO', Height='6\'2"', Weight='182 lbs', Age=27)
#
# Pandas(Index=4, _1='GK', UID=28112987, Inf='Vac', _4=nan, Player='Karlo Å½iger - Pick Player', Nat='CRO', Height='6\'1"', Weight='187 lbs', Age=22)
#
# Pandas(Index=5, _1='DM', UID=24014454, Inf='Vac', _4=nan, Player='Oliver Petrak - Pick Player', Nat='CRO', Height='6\'1"', Weight='182 lbs', Age=32)
#
# Pandas(Index=6, _1='S8', UID=2000197230, Inf='Vac', _4=nan, Player='Kristijan Kopljar - Pick Player', Nat='CRO', Height='5\'7"', Weight='143 lbs', Age=21)
#
# Pandas(Index=7, _1='S9', UID=24064692, Inf='Vac', _4=nan, Player='Mihovil GeljiÄ\x87 - Pick Player', Nat='CRO', Height='6\'2"', Weight='189 lbs', Age=31)
#
# Pandas(Index=8, _1='DCL', UID=24064579, Inf='Vac', _4=nan, Player='Marin BrigiÄ\x87 - Pick Player', Nat='CRO', Height='6\'0"', Weight='176 lbs', Age=22)
#
# Pandas(Index=9, _1='S2', UID=24060472, Inf='Vac', _4=nan, Player='Matej MamiÄ\x87 - Pick Player', Nat='CRO', Height='5\'9"', Weight='136 lbs', Age=21)
#
# Pandas(Index=10, _1='S5', UID=24046413, Inf='Vac', _4=nan, Player='Tin KulenoviÄ\x87 - Pick Player', Nat='CRO', Height='6\'2"', Weight='169 lbs', Age=26)
#
# Pandas(Index=11, _1='DR', UID=21040533, Inf='Vac', _4=nan, Player='Kristijan MediÄ\x87 - Pick Player', Nat='BIH', Height='5\'9"', Weight='152 lbs', Age=23)
#
# Pandas(Index=12, _1='-', UID=2000266168, Inf='Vac', _4=nan, Player='Vanja Å\xa0are - Pick Player', Nat='CRO', Height='5\'9"', Weight='154 lbs', Age=19)
#
# Pandas(Index=13, _1='S14', UID=2000265220, Inf='Vac', _4=nan, Player='Marko Ivan GaÅ¡parac - Pick Player', Nat='CRO', Height='6\'6"', Weight='191 lbs', Age=22)
#
# Pandas(Index=14, _1='S13', UID=2000263850, Inf='Vac', _4=nan, Player='Filip CvitanoviÄ\x87 - Pick Player', Nat='CRO', Height='6\'1"', Weight='174 lbs', Age=27)
#
# Pandas(Index=15, _1='MCR', UID=2000224203, Inf='Vac', _4=nan, Player='Moses Zambrang Barnabas - Pick Player', Nat='NGA', Height='6\'1"', Weight='169 lbs', Age=20)
#
# Pandas(Index=16, _1='-', UID=2000205976, Inf='Vac', _4=nan, Player='Mirko SuÅ¡ak - Pick Player', Nat='CRO', Height='5\'10"', Weight='145 lbs', Age=18)
#
# Pandas(Index=17, _1='AML', UID=2000156532, Inf='Vac', _4=nan, Player='Nick Ocvirek - Pick Player', Nat='CRO', Height='5\'6"', Weight='132 lbs', Age=18)
#
# Pandas(Index=18, _1='S7', UID=2000056918, Inf='Vac', _4=nan, Player='Fran Ä\x8culjak - Pick Player', Nat='CRO', Height='5\'10"', Weight='154 lbs', Age=19)
#
# Pandas(Index=19, _1='S6', UID=24065112, Inf='Vac', _4=nan, Player='Dominik Å\xa0uart - Pick Player', Nat='CRO', Height='5\'4"', Weight='121 lbs', Age=21)
#
# Pandas(Index=20, _1='DL', UID=24058119, Inf='Vac', _4=nan, Player='Nino VukasoviÄ\x87 - Pick Player', Nat='CRO', Height='5\'7"', Weight='136 lbs', Age=22)
#
# Pandas(Index=21, _1='S1', UID=24026904, Inf='Vac', _4=nan, Player='Toni Å\xa0uÅ¡koviÄ\x87 - Pick Player', Nat='CRO', Height='6\'0"', Weight='176 lbs', Age=28)
#
# Pandas(Index=22, _1='S11', UID=24018409, Inf='Vac', _4=nan, Player='Neven LaÅ¡tro - Pick Player', Nat='BIH', Height='6\'1"', Weight='185 lbs', Age=34)
#
# Pandas(Index=23, _1='S4', UID=24013607, Inf='Vac', _4=nan, Player='Marko Guja - Pick Player', Nat='CRO', Height='5\'9"', Weight='147 lbs', Age=33)
#
# Pandas(Index=24, _1='-', UID=2000307553, Inf='Vac', _4=nan, Player='Petar AndriÄ\x87 - Pick Player', Nat='CRO', Height='5\'9"', Weight='127 lbs', Age=15)
#
# Pandas(Index=25, _1=nan, UID=2000307480, Inf='Vac', _4=nan, Player='Ivan OmaziÄ\x87 - Pick Player', Nat='CRO', Height='6\'4"', Weight='171 lbs', Age=17)
#
# Pandas(Index=26, _1=nan, UID=2000298220, Inf='Vac', _4=nan, Player='Matej Jurki - Pick Player', Nat='CRO', Height='6\'2"', Weight='163 lbs', Age=17)
#
# Pandas(Index=27, _1=nan, UID=2000298216, Inf='Vac', _4=nan, Player='Tarik JaÅ¡areviÄ\x87 - Pick Player', Nat='BIH', Height='6\'2"', Weight='167 lbs', Age=18)
#
# Pandas(Index=28, _1=nan, UID=2000284366, Inf='Vac', _4=nan, Player='Davin Randall - Pick Player', Nat='USA', Height='5\'10"', Weight='156 lbs', Age=18)
#
# Pandas(Index=29, _1=nan, UID=2000279722, Inf='Vac', _4=nan, Player='Mihael Bugarija - Pick Player', Nat='CRO', Height='5\'9"', Weight='138 lbs', Age=16)
#
# Pandas(Index=30, _1=nan, UID=2000247866, Inf='Vac', _4=nan, Player='Lovro Lazar - Pick Player', Nat='CRO', Height='5\'7"', Weight='136 lbs', Age=17)
#
# Pandas(Index=31, _1='S15', UID=2000227110, Inf='Vac', _4=nan, Player='Filip Djevelekaj - Pick Player', Nat='CRO', Height='5\'11"', Weight='169 lbs', Age=19)
#
# Pandas(Index=32, _1=nan, UID=2000223761, Inf='Vac', _4=nan, Player='Petar AntolkoviÄ\x87 - Pick Player', Nat='CRO', Height='5\'7"', Weight='136 lbs', Age=18)
#
# Pandas(Index=33, _1='S10', UID=2000223757, Inf='Vac', _4=nan, Player='Filip MiÅ¡kiÄ\x87 - Pick Player', Nat='CRO', Height='6\'2"', Weight='180 lbs', Age=18)
#
# Pandas(Index=34, _1=nan, UID=2000223756, Inf='Vac', _4=nan, Player='David DoÅ¡en - Pick Player', Nat='CRO', Height='5\'11"', Weight='152 lbs', Age=17)
#
# Pandas(Index=35, _1=nan, UID=2000213982, Inf='Vac', _4=nan, Player='Domagoj RegetaÅ¡ - Pick Player', Nat='CRO', Height='5\'8"', Weight='125 lbs', Age=17)
#
# Pandas(Index=36, _1=nan, UID=2000156736, Inf='U21', _4=nan, Player='Domagoj Gracin - Pick Player', Nat='CRO', Height='6\'0"', Weight='169 lbs', Age=20)
#
# Pandas(Index=37, _1=nan, UID=2000120840, Inf='Vac', _4=nan, Player='Ivan Bjelivuk - Pick Player', Nat='CRO', Height='6\'0"', Weight='176 lbs', Age=18)
#
# Pandas(Index=38, _1='S12', UID=2000046600, Inf='Vac', _4=nan, Player='Ante MatiÄ\x87 - Pick Player', Nat='CRO', Height='5\'11"', Weight='163 lbs', Age=19)
#
# Pandas(Index=39, _1=nan, UID=2000227997, Inf='Vac', _4=nan, Player='Daniel KlariÄ\x87 - Pick Player', Nat='CRO', Height='6\'0"', Weight='138 lbs', Age=18)
#
# Pandas(Index=40, _1=nan, UID=2000156732, Inf='Vac', _4=nan, Player='Toni Gulam - Pick Player', Nat='CRO', Height='5\'10"', Weight='152 lbs', Age=18)

# %%
#headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36 Edg/118.0.2088.76'}
#url = 'https://www.transfermarkt.com/nk-sesvete/kader/verein/25029/saison_id/2023/plus/1'
#response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.content, "html.parser")
results = soup.find(id="yw1")
print(results)

# %%
# !pip install keyboard
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting keyboard
#   Downloading keyboard-0.13.5-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.1 kB ? eta -:--:--
#      -------------- ------------------------- 20.5/58.1 kB ? eta -:--:--
#      -------------------- ----------------- 30.7/58.1 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 58.1/58.1 kB 439.1 kB/s eta 0:00:00
# Installing collected packages: keyboard
# Successfully installed keyboard-0.13.5

# %%
from pyautogui import *
import cv2
import pyautogui
import time
import keyboard
import numpy as np
import random
import pprint

def group_locations(locations, threshold=10):
    """
    Group nearby locations to treat them as a single location.
    """
    grouped = []
    for loc in locations:
        if not grouped:
            grouped.append([loc])
        else:
            match = False
            for group in grouped:
                if abs(group[0][0] - loc[0]) < threshold and abs(group[0][1] - loc[1]) < threshold:
                    group.append(loc)
                    match = True
                    break
            if not match:
                grouped.append([loc])
    return [tuple(np.mean(g, axis=0).astype(int)) for g in grouped]


# Load the reference image and ensure it is in the correct format
reference_image_path = 'green_space_near_player.png'
reference_image = cv2.imread(reference_image_path, cv2.IMREAD_COLOR)

# Verify that the reference image is loaded properly
if reference_image is None:
    raise ValueError("Reference image not found or unable to load.")

# Define the region of the screen to capture (x, y, width, height)
region_bot_right_x, region_bot_right_y = (1189, 2055) 
region = (1076, 412, (region_bot_right_x - 1076), (region_bot_right_y - 412))

# GLOBALS
HOVER_DURATION = 0.2
# Bookmark link in bottom left 
INDY_TRAINING_AREA = (1387, 179)
# Location of first player row top left
TOP_PLAYER_AREA = (1267, 405)

# Roughly equivalent to number of players that 
# have > 7.0 scores in total. 
PLAYERS_TO_PRAISE = 17  # Start with 17 and see how far we get

# Top right praise button, white rectangle top right
# We aim for the white baloon
TOP_RIGHT_PRAISE_BUTTON = (3474,284)

# Praise button in the pop-up dialog after hitting
# top right praise button
MODAL_PRAISE_BUTTON = (1597, 1018)

# End the quick chat in modal pop-up
END_QC_BUTTON = (2759, 317)


# Define separate move and click functions
def my_move(coord_tuple):
    x, y = coord_tuple
    pyautogui.moveTo(x, y, duration=HOVER_DURATION)


def my_click():
    pyautogui.mouseDown()
    #time.sleep(0.1)
    pyautogui.mouseUp()

    
def orientate():
    # Training area setup
    time.sleep(5)

    # Navigate to Training Menu using FM shortcut
    pyautogui.hotkey('ctrl', 'r')
    time.sleep(1)

    # Click on Individual Training
    time.sleep(2)
    my_move(INDY_TRAINING_AREA)
    my_click()
    
    # Click first player
    my_move(TOP_PLAYER_AREA)
    my_click()
    

# To display mouse position
# pyautogui.displayMousePosition()


def my_praise_click():
    my_move(TOP_RIGHT_PRAISE_BUTTON)
    my_click()
    # Click 1st praise choice
    my_move(MODAL_PRAISE_BUTTON)
    my_click()
    # End chat 
    my_move(END_QC_BUTTON)
    my_click()

    
def praise_button_exists(button):
    x, y = button
    return pyautogui.pixel(x, y) == (255,255,255)


def click_praise_buttons():
    my_move(TOP_RIGHT_PRAISE_BUTTON)
    my_click()
    # Click 1st praise choice
    my_move(MODAL_PRAISE_BUTTON)
    my_click()
    # End chat 
    my_move(END_QC_BUTTON)
    my_click()


if __name__ == "__main__":
    # Provide time to move alt-tab to app
    time.sleep(2)
    # Go to Training>Indivdual menus
    orientate()

    # Set first position on first player and mouse click
    # first_player_button = (1267, 385)
    #my_move(TOP_PLAYER_AREA)
    #my_click()

    # Take a screenshot of the specified region
    screenshot = pyautogui.screenshot(region=region)
    screenshot = np.array(screenshot)
    screenshot = cv2.cvtColor(screenshot, cv2.COLOR_RGB2BGR)

    # Ensure both images are of the same type (either both grayscale or both color)
    # If using grayscale, uncomment the following lines:
    # reference_image = cv2.cvtColor(reference_image, cv2.COLOR_BGR2GRAY)
    # screenshot = cv2.cvtColor(screenshot, cv2.COLOR_BGR2GRAY)    

    # Find the reference image within the screenshot
    result = cv2.matchTemplate(screenshot, reference_image, cv2.TM_CCOEFF_NORMED)


    # Define a threshold
    threshold = 0.80

    # Get the locations where the matches exceed the threshold
    locations = np.where(result >= threshold)
    locations = list(zip(*locations[::-1]))

    # Group the locations
    grouped_locations = group_locations(locations)
    
    # Pretty print locations detected
    #pprint.pprint(locations)
    
    # Process each matching location
    i = 0
    for loc in grouped_locations:
        # Calculate the center point
        center_x = loc[0] + int(reference_image.shape[1] / 2)
        center_y = loc[1] + int(reference_image.shape[0] / 2)

        # Add the region's offset to get the absolute screen position
        screen_x = region[0] + center_x
        screen_y = region[1] + center_y

        # Perform the click and praise action
        pyautogui.click(screen_x, screen_y)
        print(f"Clicked {screen_x}, {screen_y} and now sleeping" )
        time.sleep(0.5)  # Adjust sleep time as needed
        # Add your 'praise player' code here
        if praise_button_exists(TOP_RIGHT_PRAISE_BUTTON):
            my_praise_click()
        # Diagnostic code in case we need to bug fix
        #i += 1
        #if i > 5:
        #    break
        # Optionally, add a small delay between processing each location
        time.sleep(0.2)
# Out:
# Clicked 1102, 458 and now sleeping
# Clicked 1102, 557 and now sleeping
# Clicked 1102, 656 and now sleeping
# Clicked 1102, 755 and now sleeping
# Clicked 1102, 854 and now sleeping
# Clicked 1102, 953 and now sleeping
